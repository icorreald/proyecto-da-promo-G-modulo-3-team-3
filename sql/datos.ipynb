# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_5268\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("../csv-archivos/employees.csv", index_col=0)
df
# Out:
#       employee_number gender  date_birth
# 0                 162      m        1972
# 1                 259      m        1971
# 2                 319      m        1981
# 5                1900      f        1975
# 6                  81      f        1964
# ...               ...    ...         ...
# 1568             3637      f        1995
# 1569             3638      f        1997
# 1574             3643      f        1992
# 1577             3646      m        1984
# 1579             3648      m        1977
#
# [1499 rows x 3 columns]

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
lista1= df.values.tolist()

# %%
lista_definitiva = [tuple(empleado) for empleado in lista1]

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='abc_company')

mycursor = cnx.cursor()
query = "INSERT INTO employees (employee_number,gender,date_birth) VALUES (%s, %s, %s)"
val = lista_definitiva
try: 
    mycursor.executemany(query, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 1499 registro/s insertado/s.

# %%
df_ed = pd.read_csv("../csv-archivos/employee_details.csv", index_col=0)
df_ed
# Out:
#       Unnamed: 0  employee_number              department  \
# 0              0              162                     NaN
# 1              1              259                     NaN
# 2              2              319  research & development
# 3              5             1900  research & development
# 4              6               81                     NaN
# ...          ...              ...                     ...
# 1575        1568             3637                   sales
# 1576        1569             3638                     NaN
# 1577        1574             3643                     NaN
# 1578        1577             3646                     NaN
# 1579        1579             3648                     NaN
#
#                        job_role  job_level  job_involvement  years_at_company  \
# 0             research director          5                3                20
# 1                       manager          5                2                33
# ...

# %%
df_ed.drop(columns ='Unnamed: 0', inplace = True)

# %%
df_ed.columns
# Out:
# Index(['employee_number', 'department', 'job_role', 'job_level',
#        'job_involvement', 'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'training_times_last_year', 'remote_work',
#        'performance_rating', 'attrition', 'marital_status',
#        'distance_from_home', 'education', 'education_field',
#        'total_working_years', 'num_companies_worked'],
#       dtype='object')

# %%
lista2= df_ed.values.tolist()

# %%
lista_definitiva2 = [tuple(empleado) for empleado in lista2]

# %%
df_ed
# Out:
#       employee_number              department                   job_role  \
# 0                 162                     NaN          research director
# 1                 259                     NaN                    manager
# 2                 319  research & development                    manager
# 3                1900  research & development                    manager
# 4                  81                     NaN            sales executive
# ...               ...                     ...                        ...
# 1575             3637                   sales            sales executive
# 1576             3638                     NaN         research scientist
# 1577             3643                     NaN  healthcare representative
# 1578             3646                     NaN            sales executive
# 1579             3648                     NaN     manufacturing director
#
#       job_level  job_involvement  years_at_company  \
# ...

# %%
lista_definitiva2
# Out:
# [(162,
#   nan,
#   'research director',
#   5,
#   3,
#   20,
#   15,
#   15,
#   5,
#   True,
#   3.0,
#   False,
#   nan,
#   6,
#   3,
#   nan,
#   nan,
#   7),
#  (259,
#   nan,
#   'manager',
#   5,
#   2,
#   33,
#   11,
#   9,
#   5,
#   True,
#   3.0,
#   False,
#   nan,
#   1,
#   4,
#   'life sciences',
#   34.0,
#   0),
#  (319,
#   'research & development',
#   'manager',
#   5,
#   3,
#   22,
#   11,
#   15,
#   3,
#   True,
#   3.0,
#   False,
#   'married',
#   4,
#   2,
#   'technical degree',
#   22.0,
#   1),
#  (1900,
#   'research & development',
#   'manager',
#   4,
#   3,
#   22,
#   4,
#   7,
#   3,
#   True,
#   3.0,
#   False,
#   nan,
#   22,
#   3,
#   'medical',
#   nan,
#   3),
#  (81,
#   nan,
#   'sales executive',
#   3,
#   3,
#   21,
#   7,
#   9,
#   3,
#   nan,
#   3.0,
#   False,
#   nan,
#   25,
#   3,
#   'life sciences',
#   28.0,
#   7),
#  (387,
#   nan,
#   'sales executive',
#   2,
#   3,
#   20,
#   11,
#   6,
#   3,
#   False,
#   4.0,
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='ABC_COMPANY')

mycursor = cnx.cursor()
query = "INSERT INTO employee_details (employee_number,department,job_role,job_level,job_involvement,years_at_company,years_since_last_promotion,years_with_current_manager,training_times_last_year,remote_work,performance_rating,attrition,marital_status,distance_from_home,education,education_field,total_working_years,num_companies_worked) VALUES (%s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s)"
val = lista_definitiva2
try: 
    mycursor.executemany(query, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 1580 registro/s insertado/s.

# %%
df_ec = pd.read_csv("../csv-archivos/economics.csv", index_col=0)
df_ec
# Out:
#       employee_number  monthly_income  hourly_rate  monthly_rate  daily_rate  \
# 0                 162         19537.0         51.0          6462       684.0
# 1                 259         19999.0         65.0          5678       699.0
# 2                 319         19232.0         58.0          4933       532.0
# 5                1900         17174.0         58.0          2437       117.0
# 6                  81             NaN         99.0          2354      1435.0
# ...               ...             ...          ...           ...         ...
# 1568             3637             NaN         81.0          3698       760.0
# 1569             3638          2366.0         88.0         20898         NaN
# 1574             3643             NaN         41.0         17369       616.0
# 1577             3646             NaN         41.0          2560       903.0
# 1579             3648         10845.0         75.0         24208       566.0
#
# ...

# %%
lista3= df_ec.values.tolist()

# %%
lista_definitiva3 = [tuple(empleado) for empleado in lista3]

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='abc_company')

mycursor = cnx.cursor()
query = "INSERT INTO economic(employee_number,monthly_income,hourly_rate,monthly_rate,daily_rate,percent_salary_hike,stock_option_level,business_travel,over_time) VALUES (%s, %s,%s, %s, %s,%s, %s, %s,%s)"
val = lista_definitiva3
try: 
    mycursor.executemany(query, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 1580 registro/s insertado/s.

# %%
df_sa = pd.read_csv("../csv-archivos/satisfaction.csv", index_col=0)
df_sa
# Out:
#       employee_number  environment_satisfaction  job_satisfaction  \
# 0                 162                       1.0                 3
# 1                 259                       3.0                 3
# 2                 319                       3.0                 4
# 5                1900                       4.0                 4
# 6                  81                       1.0                 1
# ...               ...                       ...               ...
# 1568             3637                       NaN                 2
# 1569             3638                       3.0                 3
# 1574             3643                       4.0                 4
# 1577             3646                       NaN                 3
# 1579             3648                       4.0                 3
#
#       relationship_satisfaction  work_life_balance
# 0                             3                3.0
# 1                             1                3.0
# ...

# %%
df_sa.columns
# Out:
# Index(['employee_number', 'environment_satisfaction', 'job_satisfaction',
#        'relationship_satisfaction', 'work_life_balance'],
#       dtype='object')

# %%
lista4= df_sa.values.tolist()

# %%
lista_definitiva4 = [tuple(empleado) for empleado in lista4]

# %%
lista_definitiva4
# Out:
# [(162.0, 1.0, 3.0, 3.0, 3.0),
#  (259.0, 3.0, 3.0, 1.0, 3.0),
#  (319.0, 3.0, 4.0, 4.0, nan),
#  (1900.0, 4.0, 4.0, 2.0, 3.0),
#  (81.0, 1.0, 1.0, 4.0, 2.0),
#  (387.0, 2.0, 3.0, 3.0, 3.0),
#  (999.0, 1.0, 3.0, 2.0, 4.0),
#  (1035.0, 2.0, 3.0, 2.0, 3.0),
#  (58.0, 2.0, 3.0, 4.0, 3.0),
#  (558.0, 3.0, 3.0, 4.0, 3.0),
#  (825.0, 4.0, 2.0, 4.0, 3.0),
#  (1712.0, 3.0, 3.0, 4.0, 2.0),
#  (73.0, 1.0, 4.0, 3.0, 3.0),
#  (820.0, 3.0, 4.0, 3.0, 2.0),
#  (1294.0, 3.0, 2.0, 4.0, 3.0),
#  (1774.0, 4.0, 3.0, 3.0, 3.0),
#  (1815.0, nan, 3.0, 4.0, 4.0),
#  (1993.0, 1.0, 3.0, 2.0, 3.0),
#  (32.0, 3.0, 3.0, 4.0, 2.0),
#  (100.0, 3.0, 1.0, 2.0, 3.0),
#  (244.0, 2.0, 1.0, 3.0, 3.0),
#  (327.0, 4.0, 4.0, 3.0, 3.0),
#  (373.0, 4.0, 4.0, 3.0, 3.0),
#  (729.0, 4.0, 1.0, 3.0, 3.0),
#  (830.0, 3.0, 3.0, 3.0, 3.0),
#  (981.0, 3.0, 3.0, 3.0, 4.0),
#  (1042.0, 3.0, 1.0, 3.0, 3.0),
#  (1080.0, 4.0, 1.0, 1.0, 3.0),
#  (1995.0, 4.0, 2.0, 1.0, nan),
#  (145.0, 1.0, 1.0, 3.0, 2.0),
#  (158.0, 3.0, 4.0, 4.0, 4.0),
# ...

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='abc_company')

mycursor = cnx.cursor()
query = "INSERT INTO satisfaction(employee_number,environment_satisfaction,job_satisfaction,relationship_satisfaction, work_life_balance) VALUES (%s, %s,%s, %s, %s)"
val = lista_definitiva4
try: 
    mycursor.executemany(query, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")
except mysql.connector.Error as err:
    print(err)
    print("Error Code:", err.errno)
    print("SQLSTATE", err.sqlstate)
    print("Message", err.msg)
# Out:
# 1580 registro/s insertado/s.

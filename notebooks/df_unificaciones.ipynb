# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../csv-archivos/HR RAW DATA.csv")

# %%
df
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# 2      Research & Development                  4          2  Technical Degree
# 3                          NaN                 2          4           Medical
# 4                          NaN                 3          3  Technical Degree
# ...                        ...               ...        ...               ...
# 1609                       NaN                 3          1     Life Sciences
# 1610                       NaN                 4          2               NaN
# 1611                       NaN               -13          5               NaN
# 1612                       NaN                 8          4  Technical Degree
# 1613                       NaN                 7          2           Medical
#
#       employeecount  ... YearsAtCompany  YearsInCurrentRole  \
# 0                 1  ...             20                 NaN
# 1                 1  ...             33                 NaN
# 2                 1  ...             22                 NaN
# 3                 1  ...             20                 NaN
# 4                 1  ...             19                 NaN
# ...             ...  ...            ...                 ...
# 1609              1  ...             16                 NaN
# 1610              1  ...              9                 NaN
# 1611              1  ...              8                 NaN
# 1612              1  ...              7                 NaN
# 1613              1  ...              8                 NaN
#
#       YearsSinceLastPromotion YEARSWITHCURRMANAGER  SameAsMonthlyIncome  \
# 0                          15                   15              19537,0
# 1                          11                    9              19999,0
# 2                          11                   15              19232,0
# 3                           5                    6              17169,0
# 4                           2                    8                  NaN
# ...                       ...                  ...                  ...
# 1609                        3                    7              10325,0
# 1610                        0                    8               4447,0
# 1611                        0                    7                  NaN
# 1612                        0                    7                  NaN
# 1613                        0                    7              10845,0
#
#       DateBirth       Salary                       RoleDepartament  \
# 0          1972  1000000000$                                   NaN
# 1          1971  1000000000$                                   NaN
# 2          1981  1000000000$   ManaGER  -  Research & Development
# 3          1976  1000000000$                                   NaN
# 4          1977  1000000000$                                   NaN
# ...         ...          ...                                   ...
# 1609       1987  1000000000$                                   NaN
# 1610       1978  1000000000$                                   NaN
# 1611       1984  1000000000$                                   NaN
# 1612       1987  1000000000$                                   NaN
# 1613       1977  1000000000$                                   NaN
#
#      NUMBERCHILDREN RemoteWork
# 0               NaN        Yes
# 1               NaN          1
# 2               NaN          1
# 3               NaN      False
# 4               NaN          0
# ...             ...        ...
# 1609            NaN          0
# 1610            NaN          1
# 1611            NaN        Yes
# 1612            NaN       True
# 1613            NaN          0
#
# [1614 rows x 42 columns]

# %%
df["employeenumber"].dtype
# Out:
# dtype('O')

# %%
fila, columna = df[df == 'thirty-two'].stack().index[0]
print(fila)
print(columna)
# Out:
# 1293
# Age

# %%
#Columna Age

# %%
df.iloc[31,1] = 47

# %%
df.iloc[79,1] = 58

# %%
df.iloc[216,1] = 36

# %%
df.iloc[357,1] = 55

# %%
df.iloc[411,1] = 52

# %%
df.iloc[426,1] = 31

# %%
df.iloc[593,1] = 30

# %%
df.iloc[1198,1] = 26

# %%
df.iloc[1226,1] = 37

# %%
df.iloc[1293,1] = 32

# %%
df.iloc[1325,1] = 24

# %%
df.iloc[1584,1] = 32

# %%
df['Age'] = df['Age'].astype(int)

# %%
#Attrition

# %%
df['Attrition'] = df['Attrition'].replace('No', 'False'). replace('Yes', 'True')

# %%
df['Attrition'] = df['Attrition'].astype(bool)

# %%
#Business Travel

# %%
df['BusinessTravel'] = df['BusinessTravel'].replace("non-travel", "no").replace("travel_rarely", "rarely").replace("travel_frequently", "frequently")

# %%
#Daily Rate

# %%
df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")
# Out:
# /tmp/ipykernel_28822/315446460.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")

# %%
df["DailyRate"] = df["DailyRate"].astype(float)

# %%
#Department

# %%
df["Department"] = df["Department"].str.strip()

# %%
#Distance From Home

# %%
df["DistanceFromHome"] = abs(df["DistanceFromHome"])

# %%
#Education Field

# %%
df["EducationField"] = df["EducationField"].str.lower()

# %%
#employeecount

# %%
df = df.drop('employeecount', axis=1)

# %%
#employeenumber

# %%
df["employeenumber"] = df["employeenumber"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
#NO CONSIGO PASAR A INT LO HE PROBADO TUTOOOO

# %% [markdown]
# ## ISA

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['JobRole'] = df['JobRole'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.replace('marreid', 'married')
df['Gender'] = df['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df['HourlyRate'] = df['HourlyRate'].replace('Not Available', np.nan)

# %% [markdown]
# ## MIRNA

# %%
df['Over18'].value_counts()
# Out:
# Y    713
# Name: Over18, dtype: int64

# %%
df['Over18'] = df['Over18'].replace('Y', True)

# %%
df['OverTime'] = df['OverTime'].replace({'Yes': True, 'No': False})

# %%
df["PercentSalaryHike"] = (df["PercentSalaryHike"]).astype(float) / 100

# %%
df['PerformanceRating'] = df['PerformanceRating'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['StandardHours'] = df['StandardHours'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['TOTALWORKINGYEARS'] = df["TOTALWORKINGYEARS"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %% [markdown]
# ## JOHANNA

# %%
df['Salary'] = df['Salary'].str.replace('$', '').astype(int)
# Out:
# /tmp/ipykernel_28822/1531604466.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary'] = df['Salary'].str.replace('$', '').astype(int)

# %%
df['RoleDepartament'] = df['RoleDepartament'].str.lower()

# %%
df.drop(['NUMBERCHILDREN'], axis = 1, inplace=True)

# %%
df['RemoteWork'] = df['RemoteWork'].replace(['Yes', 'yes' '1'], True).replace(['0', 'false'], False)

# %%
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['SameAsMonthlyIncome'] = df['SameAsMonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
# cambiamos nulos === 99999
df['RoleDepartament'] == df['RoleDepartament'].fillna(99999)

# eliminamos el role job
lista_vacia = []

for dato in df['RoleDepartament']:
    dato = str(dato)
    if '-' in dato:
        dato = dato.split('- ')
        lista_vacia.append(dato[-1].strip())
    else:
        lista_vacia.append(dato)


# volcamos datos nuevos
df['RoleDepartament'] = lista_vacia

# %%
# cambiamos todos los 99999 a NaN
df.replace(99999, None, inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.sample(15)
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 1483        1483   33       True             no     1038.0
# 1320        1320   29       True            NaN     1396.0
# 1464        1464   31       True            NaN     1276.0
# 1443        1443   31       True         rarely      359.0
# 623          623   40       True            NaN      299.0
# 955          955   32       True            NaN        NaN
# 1188        1188   28       True         rarely     1169.0
# 1281        1281   43       True         rarely     1001.0
# 1507        1507   40       True         rarely     1137.0
# 125          125   36       True         rarely      164.0
# 690          690   58       True            NaN      390.0
# 443          443   44       True            NaN      602.0
# 981          981   30       True            NaN      109.0
# 1130        1130   58       True     frequently     1216.0
# 433          433   40       True         rarely      898.0
#
#                   Department  DistanceFromHome  Education   EducationField  \
# 1483                   Sales                 8          1    life sciences
# 1320                     NaN                10          3              NaN
# 1464                     NaN                 2          1          medical
# 1443                     NaN                18          5  human resources
# 623                      NaN                25          4              NaN
# 955                      NaN                13          4    life sciences
# 1188                     NaN                 8          2          medical
# 1281  Research & Development                15          3              NaN
# 1507  Research & Development                 1          4              NaN
# 125                      NaN                 2          2              NaN
# 690   Research & Development                 1          4    life sciences
# 443                      NaN                 1          5              NaN
# 981                      NaN                 5          3              NaN
# 1130  Research & Development                15          4    life sciences
# 433          Human Resources                 6          2              NaN
#
#      employeenumber  EnvironmentSatisfaction Gender HourlyRate  \
# 1483           1044                        2      F         88
# 1320            749                        3      M        NaN
# 1464           1974                        4      F         59
# 1443           1842                        4      M         89
# 623            None                        4      M         57
# 955             859                        2      M         73
# 1188            869                        2      M         63
# 1281           None                       15      F         43
# 1507           None                        1      M         98
# 125             513                        2      M         61
# 690             422                        4      M         32
# 443            1642                        1      M         37
# 981            1017                        2      F         60
# 1130           1837                        1      M         87
# 433            None                        3      M         38
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 1483               2         1       sales representative                4
# 1320               3         1       sales representative                3
# 1464               1         1      laboratory technician                4
# 1443               4         1            human resources                1
# 623                2         3            sales executive                2
# 955                3         2            sales executive                4
# 1188               2         1            human resources                4
# 1281               3         3  healthcare representative                1
# 1507               3         4                    manager                1
# 125                2         3            sales executive                3
# 690                1         2  healthcare representative                3
# 443                3         2            human resources                4
# 981                3         1      laboratory technician                2
# 1130               3         4          research director                3
# 433                3         4                    manager                4
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 1483           NaN          None        21437                   0   True
# 1320        single          2642         2755                   1   True
# 1464           NaN          1129        17536                   1   True
# 1443       married          2956        21495                   0    NaN
# 623         single          None        17235                   2   True
# 955       divorced          4403         9250                   2    NaN
# 1188      divorced          None        23965                   1    NaN
# 1281       married          9985         9262                   8   True
# 1507           NaN          None        18991                   2   True
# 125        married          None         3809                   1    NaN
# 690       divorced          None        17056                   2    NaN
# 443        married          None        10503                   4    NaN
# 981            NaN          None        25725                   0    NaN
# 1130       married          None        21624                   2    NaN
# 433         single          None        17381                   1   True
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 1483      NaN               0.19                 3                         4
# 1320    False               0.11                 3                         3
# 1464      NaN               0.11                 3                         3
# 1443    False               0.17                 3                         3
# 623      True               0.12                 3                         3
# 955       NaN               0.11                 3                         3
# 1188      NaN               0.13                 3                         4
# 1281    False               0.16                 3                         1
# 1507      NaN               0.11                 3                         1
# 125       NaN               0.13                 3                         2
# 690      True               0.13                 3                         4
# 443      True               0.11                 3                         3
# 981       NaN               0.17                 3                         1
# 1130      NaN               0.14                 3                         2
# 433      True               0.21                 4                         4
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 1483          None                 0              None                      2
# 1320          None                 0                 1                      6
# 1464          None                 3              None                      4
# 1443          None                 0                 2                      4
# 623             80                 0                 9                      2
# 955             80                 1                 8                      3
# 1188            80                 1                 6                      6
# 1281          None                 1              None                      1
# 1507          None                 1                22                      3
# 125           None                 2                10                      2
# 690           None                 1              None                      2
# 443           None                 0                14                      3
# 981           None                 0                 4                      3
# 1130          None                 0                23                      3
# 433             80                 0                21                      2
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 1483             2,0               2               None
# 1320             NaN               1               None
# 1464             3,0               1               None
# 1443             3,0               1               None
# 623              3,0               5               None
# 955              2,0               5               None
# 1188             3,0               5               None
# 1281             2,0               1               None
# 1507             NaN              19               None
# 125              3,0              10               None
# 690              3,0               5               None
# 443              3,0              10               None
# 981              3,0               3               None
# 1130             3,0               2               None
# 433              3,0              21               None
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 1483                        2                     2                None
# 1320                        0                     0                2642
# 1464                        0                     0                1129
# 1443                        0                     0                2956
# 623                         1                     0                None
# 955                         0                     3                4403
# 1188                        0                     4                None
# 1281                        0                     0                9985
# 1507                       11                    16                None
# 125                         9                     0                None
# 690                         1                     2                None
# 443                         0                     2                None
# 981                         1                     2                None
# 1130                        2                     2                None
# 433                         7                     7                None
#
#       DateBirth      Salary         RoleDepartament RemoteWork
# 1483       1990  1000000000                   sales      False
# 1320       1994  1000000000                     nan      False
# 1464       1992  1000000000                     nan       True
# 1443       1992  1000000000                     nan       True
# 623        1983  1000000000                     nan          1
# 955        1991  1000000000                     nan       True
# 1188       1995  1000000000                     nan          1
# 1281       1980  1000000000  research & development       True
# 1507       1983  1000000000  research & development       True
# 125        1987  1000000000                     nan       True
# 690        1965  1000000000  research & development       True
# 443        1979  1000000000                     nan       True
# 981        1993  1000000000                     nan       True
# 1130       1965  1000000000  research & development       True
# 433        1983  1000000000         human resources          1

# %%
df['EducationField'].dtype
# Out:
# dtype('O')

# %% [markdown]
# revisar:
#
# - cambiar NaN (o nan) por None ------JOHANNA
# - department: poner lower ------- MIRNA
# - cambiar nombres columnas ------ INÉS
# - hacer int: ------ ISA
#     - WORKLIFEBALANCE: hacer int (**y revisar**)
#     - DailyRate

# %%
df
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 0              0   51       True            NaN      684.0
# 1              1   52       True            NaN      699.0
# 2              2   42       True         rarely      532.0
# 3              3   47       True         rarely      359.0
# 4              4   46       True            NaN     1319.0
# ...          ...  ...        ...            ...        ...
# 1609        1609   36       True         rarely      530.0
# 1610        1610   45       True             no      805.0
# 1611        1611   39       True         rarely      903.0
# 1612        1612   36       True             no     1229.0
# 1613        1613   46       True            NaN      566.0
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                        NaN                 6          3               NaN
# 1                        NaN                 1          4     life sciences
# 2     Research & Development                 4          2  technical degree
# 3                        NaN                 2          4           medical
# 4                        NaN                 3          3  technical degree
# ...                      ...               ...        ...               ...
# 1609                     NaN                 3          1     life sciences
# 1610                     NaN                 4          2               NaN
# 1611                     NaN                13          5               NaN
# 1612                     NaN                 8          4  technical degree
# 1613                     NaN                 7          2           medical
#
#      employeenumber  EnvironmentSatisfaction Gender HourlyRate  \
# 0               162                        1      M         51
# 1               259                        3      M         65
# 2               319                        3      M         58
# 3              None                        1      F         82
# 4              None                        1      F         45
# ...             ...                      ...    ...        ...
# 1609            967                        3      M         51
# 1610            972                        3      M         57
# 1611           None                       13      M         41
# 1612            990                        1      M         84
# 1613           None                        4      M         75
#
#       JobInvolvement  JobLevel                 JobRole  JobSatisfaction  \
# 0                  3         5       research director                3
# 1                  2         5                 manager                3
# 2                  3         5                 manager                4
# 3                  3         4       research director                3
# 4                  4         4         sales executive                1
# ...              ...       ...                     ...              ...
# 1609               2         3         sales executive                4
# 1610               3         2   laboratory technician                2
# 1611               4         3         sales executive                3
# 1612               3         2         sales executive                4
# 1613               3         3  manufacturing director                3
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0              NaN         19537         6462                   7   True
# 1              NaN         19999         5678                   0    NaN
# 2          married         19232         4933                   1    NaN
# 3          married         17169        26703                   3   True
# 4         divorced          None         7739                   2   True
# ...            ...           ...          ...                 ...    ...
# 1609       married         10325         5518                   1   True
# 1610           NaN          4447        23163                   1    NaN
# 1611        single          None         2560                   0    NaN
# 1612      divorced          None        25952                   4    NaN
# 1613           NaN         10845        24208                   6   True
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0       False               0.13                 3                         3
# 1         NaN               0.14                 3                         1
# 2       False               0.11                 3                         4
# 3         NaN               0.19                 3                         2
# 4       False               0.12                 3                         4
# ...       ...                ...               ...                       ...
# 1609      NaN               0.11              None                         1
# 1610      NaN               0.12                 3                         2
# 1611    False               0.18                 3                         4
# 1612    False               0.13              None                         4
# 1613      NaN               0.13                 3                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 0             None                 0              None                      5
# 1             None                 1                34                      5
# 2             None                 0                22                      3
# 3             None                 2              None                      2
# 4             None                 1              None                      5
# ...            ...               ...               ...                    ...
# 1609          None                 1              None                      6
# 1610          None                 0              None                      5
# 1611          None                 0                 9                      3
# 1612          None                 2                12                      3
# 1613          None                 1              None                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 0                3,0              20               None
# 1                3,0              33               None
# 2                NaN              22               None
# 3                NaN              20               None
# 4                3,0              19               None
# ...              ...             ...                ...
# 1609             3,0              16               None
# 1610             2,0               9               None
# 1611             3,0               8               None
# 1612             3,0               7               None
# 1613             3,0               8               None
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 0                          15                    15               19537
# 1                          11                     9               19999
# 2                          11                    15               19232
# 3                           5                     6               17169
# 4                           2                     8                None
# ...                       ...                   ...                 ...
# 1609                        3                     7               10325
# 1610                        0                     8                4447
# 1611                        0                     7                None
# 1612                        0                     7                None
# 1613                        0                     7               10845
#
#       DateBirth      Salary         RoleDepartament RemoteWork
# 0          1972  1000000000                     nan       True
# 1          1971  1000000000                     nan          1
# 2          1981  1000000000  research & development          1
# 3          1976  1000000000                     nan      False
# 4          1977  1000000000                     nan      False
# ...         ...         ...                     ...        ...
# 1609       1987  1000000000                     nan      False
# 1610       1978  1000000000                     nan          1
# 1611       1984  1000000000                     nan       True
# 1612       1987  1000000000                     nan       True
# 1613       1977  1000000000                     nan      False
#
# [1614 rows x 40 columns]

# %%
df['BusinessTravel'].dtype
# Out:
# dtype('O')

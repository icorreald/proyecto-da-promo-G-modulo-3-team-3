# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../csv-archivos/HR RAW DATA.csv")

# %%
df
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# 2      Research & Development                  4          2  Technical Degree
# 3                          NaN                 2          4           Medical
# 4                          NaN                 3          3  Technical Degree
# ...                        ...               ...        ...               ...
# 1609                       NaN                 3          1     Life Sciences
# 1610                       NaN                 4          2               NaN
# 1611                       NaN               -13          5               NaN
# 1612                       NaN                 8          4  Technical Degree
# 1613                       NaN                 7          2           Medical
#
#       employeecount employeenumber  EnvironmentSatisfaction  Gender  \
# 0                 1          162,0                        1       0
# 1                 1          259,0                        3       0
# 2                 1          319,0                        3       0
# 3                 1            NaN                        1       1
# 4                 1            NaN                        1       1
# ...             ...            ...                      ...     ...
# 1609              1          967,0                        3       0
# 1610              1          972,0                        3       0
# 1611              1            NaN                       13       0
# 1612              1          990,0                        1       0
# 1613              1            NaN                        4       0
#
#      HourlyRate  JobInvolvement  JobLevel                   JobRole  \
# 0            51               3         5        resEArch DIREcToR
# 1            65               2         5                  ManAGeR
# 2            58               3         5                  ManaGER
# 3            82               3         4        ReseArCH DIrECtOr
# 4            45               4         4          sAleS EXECUtIve
# ...         ...             ...       ...                       ...
# 1609         51               2         3          saLEs ExeCUTiVe
# 1610         57               3         2    LAboRaTOry tECHNiCIAn
# 1611         41               4         3          sAlES ExECUTivE
# 1612         84               3         2          SaLes ExecUtIVe
# 1613         75               3         3   mAnUfactURInG DiRECTOr
#
#       JobSatisfaction MaritalStatus MonthlyIncome  MonthlyRate  \
# 0                   3           NaN       19537,0         6462
# 1                   3           NaN       19999,0         5678
# 2                   4       Married       19232,0         4933
# 3                   3       Married       17169,0        26703
# 4                   1      Divorced           NaN         7739
# ...               ...           ...           ...          ...
# 1609                4       Married       10325,0         5518
# 1610                2           NaN        4447,0        23163
# 1611                3        Single           NaN         2560
# 1612                4      Divorced           NaN        25952
# 1613                3           NaN       10845,0        24208
#
#       NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike PerformanceRating  \
# 0                      7      Y       No                 13               3,0
# 1                      0    NaN      NaN                 14               3,0
# 2                      1    NaN       No                 11               3,0
# 3                      3      Y      NaN                 19               3,0
# 4                      2      Y       No                 12               3,0
# ...                  ...    ...      ...                ...               ...
# 1609                   1      Y      NaN                 11               NaN
# 1610                   1    NaN      NaN                 12               3,0
# 1611                   0    NaN       No                 18               3,0
# 1612                   4    NaN       No                 13               NaN
# 1613                   6      Y      NaN                 13               3,0
#
#       RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                            3           NaN                 0
# 1                            1           NaN                 1
# 2                            4           NaN                 0
# 3                            2           NaN                 2
# 4                            4           NaN                 1
# ...                        ...           ...               ...
# 1609                         1           NaN                 1
# 1610                         2           NaN                 0
# 1611                         4           NaN                 0
# 1612                         4           NaN                 2
# 1613                         2           NaN                 1
#
#      TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0                  NaN                      5             3,0              20
# 1                 34,0                      5             3,0              33
# 2                 22,0                      3             NaN              22
# 3                  NaN                      2             NaN              20
# 4                  NaN                      5             3,0              19
# ...                ...                    ...             ...             ...
# 1609               NaN                      6             3,0              16
# 1610               NaN                      5             2,0               9
# 1611               9,0                      3             3,0               8
# 1612              12,0                      3             3,0               7
# 1613               NaN                      3             3,0               8
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                   NaN                       15                    15
# 1                   NaN                       11                     9
# 2                   NaN                       11                    15
# 3                   NaN                        5                     6
# 4                   NaN                        2                     8
# ...                 ...                      ...                   ...
# 1609                NaN                        3                     7
# 1610                NaN                        0                     8
# 1611                NaN                        0                     7
# 1612                NaN                        0                     7
# 1613                NaN                        0                     7
#
#      SameAsMonthlyIncome  DateBirth       Salary  \
# 0                19537,0       1972  1000000000$
# 1                19999,0       1971  1000000000$
# 2                19232,0       1981  1000000000$
# 3                17169,0       1976  1000000000$
# 4                    NaN       1977  1000000000$
# ...                  ...        ...          ...
# 1609             10325,0       1987  1000000000$
# 1610              4447,0       1978  1000000000$
# 1611                 NaN       1984  1000000000$
# 1612                 NaN       1987  1000000000$
# 1613             10845,0       1977  1000000000$
#
#                            RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                      NaN             NaN        Yes
# 1                                      NaN             NaN          1
# 2      ManaGER  -  Research & Development              NaN          1
# 3                                      NaN             NaN      False
# 4                                      NaN             NaN          0
# ...                                    ...             ...        ...
# 1609                                   NaN             NaN          0
# 1610                                   NaN             NaN          1
# 1611                                   NaN             NaN        Yes
# 1612                                   NaN             NaN       True
# 1613                                   NaN             NaN          0
#
# [1614 rows x 42 columns]

# %%
df["employeenumber"].dtype
# Out:
# dtype('O')

# %%
fila, columna = df[df == 'thirty-two'].stack().index[0]
print(fila)
print(columna)
# Out:
# 1293
# Age

# %%
#Columna Age

# %%
df.iloc[31,1] = 47

# %%
df.iloc[79,1] = 58

# %%
df.iloc[216,1] = 36

# %%
df.iloc[357,1] = 55

# %%
df.iloc[411,1] = 52

# %%
df.iloc[426,1] = 31

# %%
df.iloc[593,1] = 30

# %%
df.iloc[1198,1] = 26

# %%
df.iloc[1226,1] = 37

# %%
df.iloc[1293,1] = 32

# %%
df.iloc[1325,1] = 24

# %%
df.iloc[1584,1] = 32

# %%
df['Age'] = df['Age'].astype(int)

# %%
#Attrition

# %%
df['Attrition'] = df['Attrition'].replace('No', 'False'). replace('Yes', 'True')

# %%
df['Attrition'] = df['Attrition'].astype(bool)

# %%
#Business Travel

# %%
df['BusinessTravel'] = df['BusinessTravel'].replace("non-travel", "no").replace("travel_rarely", "rarely").replace("travel_frequently", "frequently")

# %%
#Daily Rate

# %%
df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")

# %%
df["DailyRate"] = df["DailyRate"].astype(float)

# %%
#Department

# %%
df["Department"] = df["Department"].str.strip()

# %%
#Distance From Home

# %%
df["DistanceFromHome"] = abs(df["DistanceFromHome"])

# %%
#Education Field

# %%
df["EducationField"] = df["EducationField"].str.lower()

# %%
#employeecount

# %%
df = df.drop('employeecount', axis=1)

# %%
#employeenumber

# %%
df["employeenumber"] = df["employeenumber"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
#NO CONSIGO PASAR A INT LO HE PROBADO TUTOOOO

# %% [markdown]
# ## ISA

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['JobRole'] = df['JobRole'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.replace('marreid', 'married')
df['Gender'] = df['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df['HourlyRate'] = df['HourlyRate'].replace('Not Available', np.nan)

# %% [markdown]
# ## MIRNA

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    713
# Name: count, dtype: int64

# %%
df['Over18'] = df['Over18'].replace('Y', True)

# %%
df['OverTime'] = df['OverTime'].replace({'Yes': True, 'No': False})

# %%
df["PercentSalaryHike"] = (df["PercentSalaryHike"]).astype(float) / 100

# %%
df['PerformanceRating'] = df['PerformanceRating'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['StandardHours'] = df['StandardHours'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['TOTALWORKINGYEARS'] = df["TOTALWORKINGYEARS"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %% [markdown]
# ## JOHANNA

# %%
df['Salary'] = df['Salary'].str.replace('$', '').astype(int)

# %%
df['RoleDepartament'] = df['RoleDepartament'].str.lower()

# %%
df.drop(['NUMBERCHILDREN'], axis = 1, inplace=True)

# %%
df['RemoteWork'] = df['RemoteWork'].replace(['Yes', 'yes' '1'], True).replace(['0', 'false'], False)

# %%
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['SameAsMonthlyIncome'] = df['SameAsMonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
# cambiamos nulos === 99999
df['RoleDepartament'] == df['RoleDepartament'].fillna(99999)

# eliminamos el role job
lista_vacia = []

for dato in df['RoleDepartament']:
    dato = str(dato)
    if '-' in dato:
        dato = dato.split('- ')
        lista_vacia.append(dato[-1].strip())
    else:
        lista_vacia.append(dato)


# volcamos datos nuevos
df['RoleDepartament'] = lista_vacia

# %%
# cambiamos todos los 99999 a NaN
df.replace(99999, None, inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.sample(15)
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 1548        1548   43       True     frequently        NaN
# 719          719   25       True            NaN      141.0
# 1236        1236   26       True            NaN     1357.0
# 231          231   53       True            NaN      447.0
# 96            96   33       True            NaN      117.0
# 703          703   26       True         rarely      703.0
# 117          117   45       True     frequently     1249.0
# 171          171   40       True            NaN      692.0
# 1167        1167   36       True     frequently      884.0
# 1524        1524   57       True         rarely      593.0
# 1175        1175   36       True     frequently      635.0
# 1118        1118   29       True         rarely      428.0
# 1312        1312   38       True            NaN      362.0
# 450          450   46       True            NaN      717.0
# 960          960   25       True            NaN      583.0
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1548                     NaN                10          4     life sciences
# 719                      NaN                 3          1               NaN
# 1236                     NaN                25          3     life sciences
# 231                      NaN                 2          3           medical
# 96    Research & Development                 9          3           medical
# 703                      NaN                28          2         marketing
# 117                      NaN                 7          3     life sciences
# 171                      NaN                11          3  technical degree
# 1167                     NaN                23          2           medical
# 1524                     NaN                 1          4           medical
# 1175                     NaN                18          1               NaN
# 1118                     NaN                 9          3               NaN
# 1312                     NaN                27          1     life sciences
# 450   Research & Development                13          4               NaN
# 960                      NaN                 4          1               NaN
#
#      employeenumber  EnvironmentSatisfaction Gender HourlyRate  \
# 1548            430                        3      F         33
# 719            None                        3      M         98
# 1236             55                        1      M         48
# 231            1472                        4      M         39
# 96             1238                        1      M         60
# 703             641                        1      M         66
# 117            None                        1      M         97
# 171            1985                        4      F         73
# 1167           2061                        3      M         41
# 1524            482                        4      M         88
# 1175            286                        2      F         73
# 1118           None                        2      F        NaN
# 1312            662                        3      F        NaN
# 450            1727                        3      M         34
# 960             885                        3      M         87
#
#       JobInvolvement  JobLevel                    JobRole  JobSatisfaction  \
# 1548               3         1      laboratory technician                4
# 719                3         2            sales executive                1
# 1236               1         1      laboratory technician                3
# 231                4         4          research director                2
# 96                 3         1         research scientist                4
# 703                3         2            sales executive                2
# 117                3         3      laboratory technician                1
# 171                3         2      laboratory technician                3
# 1167               4         2      laboratory technician                4
# 1524               3         2  healthcare representative                3
# 1175               3         1      laboratory technician                4
# 1118               1         1       sales representative                2
# 1312               3         1         research scientist                1
# 450                3         2  healthcare representative                2
# 960                2         2            sales executive                1
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 1548           NaN          2455        10675                   0   True
# 719            NaN          4194        14363                   1    NaN
# 1236        single          None        10558                   1    NaN
# 231         single         16598        19764                   4    NaN
# 96         married          None         6311                   0   True
# 703        married          None         7428                   1   True
# 117            NaN          None        20308                   1   True
# 171        married          None        26849                   1    NaN
# 1167           NaN          2571        12290                   4   True
# 1524           NaN          6755         2967                   2    NaN
# 1175        single          None         7703                   1   True
# 1118        single          2760        14630                   1    NaN
# 1312           NaN          None        14561                   3    NaN
# 450         single          None         9697                   6    NaN
# 960            NaN          4256        18154                   1   True
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 1548    False               0.19                 3                         1
# 719      True               0.18                 3                         4
# 1236      NaN               0.12                 3                         3
# 231     False               0.12                 3                         2
# 96        NaN               0.13                 3                         2
# 703       NaN               0.20                 4                         4
# 117       NaN               0.18                 3                         1
# 171       NaN               0.11              None                         1
# 1167    False               0.17                 3                         3
# 1524    False               0.11                 3                         3
# 1175      NaN               0.13                 3                         1
# 1118      NaN               0.13                 3                         3
# 1312    False               0.17                 3                         4
# 450     False               0.14                 3                         4
# 960     False               0.12                 3                         1
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 1548          None                 0              None                      5
# 719           None                 0                 5                      3
# 1236          None                 0                 1                      2
# 231           None                 0                35                      2
# 96            None                 1                15                      5
# 703           None                 2              None                      5
# 117           None                 1                24                      2
# 171           None                 1                10                      2
# 1167            80                 1                17                      3
# 1524          None                 0              None                      2
# 1175            80                 0                 8                      2
# 1118            80                 0                 2                      3
# 1312          None                 0                 8                      3
# 450           None                 0                19                      3
# 960           None                 0                 5                      1
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 1548             3,0               8               None
# 719              3,0               5               None
# 1236             2,0               1               None
# 231              2,0               9               None
# 96               3,0              14               None
# 703              4,0               5               None
# 117              3,0              24               None
# 171              4,0              10               None
# 1167             3,0               5               None
# 1524             3,0               3               None
# 1175             3,0               8               None
# 1118             3,0               2               None
# 1312             2,0               0               None
# 450              3,0              10               None
# 960              4,0               5               None
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 1548                        1                     7                2455
# 719                         0                     3                4194
# 1236                        0                     1                None
# 231                         8                     8               16598
# 96                          4                    10                None
# 703                         1                     4                None
# 117                         9                    11                None
# 171                         9                     4                None
# 1167                        0                     3                2571
# 1524                        1                     2                6755
# 1175                        1                     7                None
# 1118                        2                     2                2760
# 1312                        0                     0                None
# 450                         0                     9                None
# 960                         0                     3                4256
#
#       DateBirth      Salary         RoleDepartament RemoteWork
# 1548       1980  1000000000                     nan      False
# 719        1998  1000000000                     nan       True
# 1236       1997  1000000000                     nan      False
# 231        1970  1000000000                     nan       True
# 96         1990  1000000000  research & development      False
# 703        1997  1000000000                     nan       True
# 117        1978  1000000000                     nan        Yes
# 171        1983  1000000000                     nan       True
# 1167       1987  1000000000                     nan      False
# 1524       1966  1000000000                     nan      False
# 1175       1987  1000000000                     nan        Yes
# 1118       1994  1000000000                     nan       True
# 1312       1985  1000000000                     nan       True
# 450        1977  1000000000  research & development       True
# 960        1998  1000000000                     nan      False

# %%
df['EducationField'].dtype
# Out:
# dtype('O')

# %% [markdown]
# revisar:
#
# - cambiar NaN (o nan) por None ------JOHANNA
# - department: poner lower ------- MIRNA
# - cambiar nombres columnas ------ INÉS
# - hacer int: ------ ISA
#     - WORKLIFEBALANCE: hacer int (**y revisar**)
#     - DailyRate

# %%
df["Department"] = df["Department"].str.lower().replace("Research & Development", "research & development")

# %%
df["Department"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                            NaN
# 1                            NaN
# 2        research & development
# 3                            NaN
# 4                            NaN
#                   ...
# 1609                         NaN
# 1610                         NaN
# 1611                         NaN
# 1612                         NaN
# 1613                         NaN
# Name: Department, Length: 1614, dtype: object>

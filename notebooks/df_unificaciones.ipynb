# %%
import numpy as np
import pandas as pd
import re
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_8684\1137696326.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("../csv-archivos/HR RAW DATA.csv")

# %%
df.sample()
# Out:
#      Unnamed: 0 Age Attrition BusinessTravel DailyRate Department  \
# 369         369  36        No     non-travel   1229,0$        NaN
#
#      DistanceFromHome  Education    EducationField  employeecount  ...  \
# 369                 8          4  Technical Degree              1  ...
#
#     YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 369              7                 NaN                        0
#
#     YEARSWITHCURRMANAGER  SameAsMonthlyIncome  DateBirth       Salary  \
# 369                    7                  NaN       1987  1000000000$
#
#      RoleDepartament NUMBERCHILDREN RemoteWork
# 369              NaN            NaN        Yes
#
# [1 rows x 42 columns]

# %%
#Columna Age

# %%
def word_to_num(dato):
    
    if len(dato) > 2:
        dato = w2n.word_to_num(dato)
        return dato

    else:
        return dato

# %%
df['Age'] = df['Age'].apply(word_to_num)

# %%
#Attrition

# %%
def true_false(valor):
   
    if valor in ['Yes', 'yes', '1']:
        valor = True
    
    elif valor in ['False', 'No', '0', 'false']:
        valor = False
    

    else:
        valor = np.nan

    return valor

# %%
lista_columnas = ['Attrition', 'RemoteWork']

for columna in lista_columnas:
    df[columna] = df[columna].apply(true_false)

# %%
df['RemoteWork'] = df['RemoteWork'].apply(true_false)

# %%
#Business Travel

# %%
df['BusinessTravel'] = df['BusinessTravel'].map({"non-travel":"no", "travel_rarely":"rarely", "travel_frequently":"frequently"})

# %%
#Daily Rate

# %%
df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")

# %%
df["DailyRate"] = df["DailyRate"].astype(float)

# %%
#Department

# %%
df["Department"] = df["Department"].str.strip()

# %%
#Distance From Home

# %%
df["DistanceFromHome"] = abs(df["DistanceFromHome"])

# %%
#Education Field

# %%
df["EducationField"] = df["EducationField"].str.lower()

# %%
#employeecount

# %%
df = df.drop('employeecount', axis=1)

# %%
#employeenumber

# %%
df["employeenumber"] = df["employeenumber"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
#NO CONSIGO PASAR A INT LO HE PROBADO TUTOOOO

# %% [markdown]
# ## ISA

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['JobRole'] = df['JobRole'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.replace('marreid', 'married')
df['Gender'] = df['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df['HourlyRate'] = df['HourlyRate'].replace('Not Available', np.nan)

# %% [markdown]
# ## MIRNA

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    713
# Name: count, dtype: int64

# %%
df['Over18'] = df['Over18'].replace('Y', True)

# %%
df['OverTime'] = df['OverTime'].replace({'Yes': True, 'No': False})

# %%
df["PercentSalaryHike"] = (df["PercentSalaryHike"]).astype(float) / 100

# %%
df['PerformanceRating'] = df['PerformanceRating'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['StandardHours'] = df['StandardHours'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['TOTALWORKINGYEARS'] = df["TOTALWORKINGYEARS"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %% [markdown]
# ## JOHANNA

# %%
df['Salary'] = df['Salary'].str.replace('$', '').astype(int)

# %%
df['RoleDepartament'] = df['RoleDepartament'].str.lower()

# %%
df.drop(['NUMBERCHILDREN'], axis = 1, inplace=True)

# %%
df['RemoteWork'] = df['RemoteWork'].replace(['Yes', 'yes', '1'], True).replace(['0', 'false'], False)

# %%
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['SameAsMonthlyIncome'] = df['SameAsMonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
# cambiamos nulos === 99999
df['RoleDepartament'] == df['RoleDepartament'].fillna(99999)

# eliminamos el role job
lista_vacia = []

for dato in df['RoleDepartament']:
    dato = str(dato)
    if '-' in dato:
        dato = dato.split('- ')
        lista_vacia.append(dato[-1].strip())
    else:
        lista_vacia.append(dato)


# volcamos datos nuevos
df['RoleDepartament'] = lista_vacia

# %%
# cambiamos todos los 99999 a NaN
df.replace(99999, None, inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.sample(15)
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate Department  \
# 1586        1586   27       True     frequently      294.0        NaN
# 1402        1402   28       True            NaN      289.0        NaN
# 1473        1473   58       True         rarely      147.0        NaN
# 1004        1004   33       True            NaN      603.0        NaN
# 1216        1216   46       True         rarely      734.0        NaN
# 1035        1035   27       True     frequently      793.0        NaN
# 1197        1197   50       True         rarely     1464.0        NaN
# 1039        1039   51       True            NaN      541.0        NaN
# 1000        1000   21       True            NaN      984.0        NaN
# 249          249   34       True         rarely        NaN        NaN
# 1373        1373   22       True            NaN     1256.0        NaN
# 324          324   48       True         rarely      163.0        NaN
# 124          124   36       True            NaN      541.0        NaN
# 863          863   28       True         rarely     1158.0        NaN
# 427          427   46       True            NaN      377.0        NaN
#
#       DistanceFromHome  Education EducationField employeenumber  \
# 1586                10          2            NaN            733
# 1402                 2          2        medical           1504
# 1473                23          4        medical           None
# 1004                 9          4            NaN           1157
# 1216                 2          4            NaN           1789
# 1035                 2          1  life sciences           1371
# 1197                12          4        medical           1061
# 1039                 2          3            NaN           None
# 1000                 1          1            NaN           1131
# 249                  8          2            NaN           1823
# 1373                 3          4  life sciences           None
# 324                  2          5            NaN            595
# 124                  3          4        medical            481
# 863                  9          3            NaN           None
# 427                  9          3      marketing           1457
#
#       EnvironmentSatisfaction Gender HourlyRate  JobInvolvement  JobLevel  \
# 1586                        4      M         32               3         3
# 1402                        3      M        NaN               2         1
# 1473                        4      F         94               3         3
# 1004                        1      F         77               3         2
# 1216                        3      M         46               3         5
# 1035                        4      M         43               1         2
# 1197                       12      M         62               3         5
# 1039                        2      M         52               3         3
# 1000                        4      F         70               2         1
# 249                         2      M         92               4         2
# 1373                        3      M         48               2         1
# 324                         2      F         37               3         2
# 124                         1      M         48               2         3
# 863                         4      M         94               3         1
# 427                         1      M         52               3         3
#
#                         JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 1586     manufacturing director                1           NaN          8793
# 1402      laboratory technician                1        single          2561
# 1473  healthcare representative                4       married          None
# 1004            sales executive                1        single          8224
# 1216          research director                4           NaN          None
# 1035            sales executive                4        single          5071
# 1197          research director                3       married         19237
# 1039            sales executive                2           NaN         10596
# 1000         research scientist                2        single          2070
# 249             sales executive                3           NaN          None
# 1373         research scientist                4       married          2853
# 324             sales executive                4       married          4051
# 124             sales executive                4       married          None
# 863          research scientist                4       married          None
# 427             sales executive                4      divorced          None
#
#       MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 1586         4809                   1   True    False               0.21
# 1402         5355                   7    NaN    False               0.11
# 1473         3465                   1    NaN      NaN               0.12
# 1004        18385                   0    NaN      NaN               0.17
# 1216        14218                   7   True      NaN               0.17
# 1035        20392                   3   True    False               0.20
# 1197        12853                   2    NaN      NaN               0.11
# 1039        15395                   2    NaN      NaN               0.11
# 1000        25326                   1   True     True               0.11
# 249         22128                   1    NaN    False               0.21
# 1373         4223                   0    NaN     True               0.11
# 324         19658                   2    NaN    False               0.14
# 124          7246                   4   True    False               0.11
# 863          2613                   1    NaN    False               0.23
# 427         15986                   4    NaN    False               0.11
#
#      PerformanceRating  RelationshipSatisfaction StandardHours  \
# 1586                 4                         3          None
# 1402              None                         3          None
# 1473                 3                         4          None
# 1004                 3                         1          None
# 1216                 3                         3          None
# 1035                 4                         2          None
# 1197                 3                         4          None
# 1039                 3                         2          None
# 1000                 3                         3            80
# 249                  4                         3          None
# 1373                 3                         2          None
# 324                  3                         1          None
# 124                  3                         1          None
# 863                  4                         4          None
# 427                  3                         1          None
#
#       StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 1586                 2                 9                      4
# 1402                 0                 8                      2
# 1473                 1                40                      3
# 1004                 0                 6                      3
# 1216                 1                24                      3
# 1035                 0              None                      3
# 1197                 1                29                      2
# 1039                 0                14                      5
# 1000                 0                 2                      6
# 249                  2                10                      5
# 1373                 1                 1                      5
# 324                  1                14                      2
# 124                  1                16                      2
# 863                  1              None                      3
# 427                  1                28                      1
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 1586             2,0               9               None
# 1402             2,0               0               None
# 1473             2,0              40               None
# 1004             3,0               5               None
# 1216             3,0               2               None
# 1035             3,0               6               None
# 1197             2,0               8               None
# 1039             3,0               4               None
# 1000             4,0               2               None
# 249              3,0              10               None
# 1373             3,0               0               None
# 324              3,0               9               None
# 124              3,0              13               None
# 863              NaN               5               None
# 427              4,0               7               None
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 1586                        1                     7                8793
# 1402                        0                     0                2561
# 1473                       15                     6                None
# 1004                        0                     3                8224
# 1216                        2                     2                None
# 1035                        0                     0                5071
# 1197                        7                     7               19237
# 1039                        3                     2               10596
# 1000                        2                     2                2070
# 249                         4                     8                None
# 1373                        0                     0                2853
# 324                         6                     7                4051
# 124                         1                    12                None
# 863                         0                     4                None
# 427                         4                     3                None
#
#       DateBirth      Salary RoleDepartament RemoteWork
# 1586       1996  1000000000             nan          1
# 1402       1995  1000000000             nan       True
# 1473       1965  1000000000             nan          1
# 1004       1990  1000000000             nan      False
# 1216       1977  1000000000             nan          1
# 1035       1996  1000000000             nan      False
# 1197       1973  1000000000             nan      False
# 1039       1972  1000000000             nan          1
# 1000       2002  1000000000             nan       True
# 249        1989  1000000000             nan      False
# 1373       2001  1000000000             nan       True
# 324        1975  1000000000             nan       True
# 124        1987  1000000000             nan       True
# 863        1995  1000000000             nan          1
# 427        1977  1000000000             nan       True

# %%
df['EducationField'].dtype
# Out:
# dtype('O')

# %%
df["Department"] = df["Department"].str.lower()

# %%
df['WORKLIFEBALANCE'] = df['WORKLIFEBALANCE'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['DailyRate'] = df['DailyRate'].replace(',', '.').replace('$', '').astype(float).fillna(99999).astype(int)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'RemoteWork'],
#       dtype='object')

# %% [markdown]
# HOMOGENIZAR COLUMNAS

# %%
#creo una nueva lista para apendear los nuevos nombres
col = []
patron = re.compile(r'[a-zA-Z][a-z]*[A-Z][a-z]*') #patron que busca minusculas y mayusculas seguidas
for columna in df.columns: #itero por la lista 
    if re.search(patron, columna):
        col_sep = re.sub(r'(?<=[a-z])(?=[A-Z])', '_', columna) #cada vez que encuentro una minúscula seguida de mayúscula lo cambio por _ 
        col.append(col_sep.lower())
    else:
        col.append(columna.lower())

# %%
col
# Out:
# ['unnamed: 0',
#  'age',
#  'attrition',
#  'business_travel',
#  'daily_rate',
#  'department',
#  'distance_from_home',
#  'education',
#  'education_field',
#  'employeenumber',
#  'environment_satisfaction',
#  'gender',
#  'hourly_rate',
#  'job_involvement',
#  'job_level',
#  'job_role',
#  'job_satisfaction',
#  'marital_status',
#  'monthly_income',
#  'monthly_rate',
#  'numcompaniesworked',
#  'over18',
#  'over_time',
#  'percent_salary_hike',
#  'performance_rating',
#  'relationship_satisfaction',
#  'standard_hours',
#  'stock_option_level',
#  'totalworkingyears',
#  'training_times_last_year',
#  'worklifebalance',
#  'years_at_company',
#  'years_in_current_role',
#  'years_since_last_promotion',
#  'yearswithcurrmanager',
#  'same_as_monthly_income',
#  'date_birth',
#  'salary',
#  'role_departament',
#  'remote_work']

# %%
nuevas_columnas = ['unnamed: 0',
 'age',
 'attrition',
 'business_travel',
 'daily_rate',
 'department',
 'distance_from_home',
 'education',
 'education_field',
 'employee_number',
 'environment_satisfaction',
 'gender',
 'hourly_rate',
 'job_involvement',
 'job_level',
 'job_role',
 'job_satisfaction',
 'marital_status',
 'monthly_income',
 'monthly_rate',
 'num_companies_worked',
 'over18',
 'over_time',
 'percent_salary_hike',
 'performance_rating',
 'relationship_satisfaction',
 'standard_hours',
 'stock_option_level',
 'total_working_years',
 'training_times_last_year',
 'work_life_balance',
 'years_at_company',
 'years_in_current_role',
 'years_since_last_promotion',
 'years_with_curr_manager',
 'same_as_monthly_income',
 'date_birth',
 'salary',
 'role_departament',
 'remote_work']

# %%
#sustituyo los nombres antiguos por la nueva lista
df.columns = nuevas_columnas

# %%
df["work_life_balance"]
# Out:
#       unnamed: 0  age  attrition business_travel  daily_rate  \
# 0              0   51       True             NaN         684
# 1              1   52       True             NaN         699
# 2              2   42       True          rarely         532
# 3              3   47       True          rarely         359
# 4              4   46       True             NaN        1319
# ...          ...  ...        ...             ...         ...
# 1609        1609   36       True          rarely         530
# 1610        1610   45       True              no         805
# 1611        1611   39       True          rarely         903
# 1612        1612   36       True              no        1229
# 1613        1613   46       True             NaN         566
#
#                   department  distance_from_home  education   education_field  \
# 0                        NaN                   6          3               NaN
# 1                        NaN                   1          4     life sciences
# 2     research & development                   4          2  technical degree
# 3                        NaN                   2          4           medical
# 4                        NaN                   3          3  technical degree
# ...                      ...                 ...        ...               ...
# 1609                     NaN                   3          1     life sciences
# 1610                     NaN                   4          2               NaN
# 1611                     NaN                  13          5               NaN
# 1612                     NaN                   8          4  technical degree
# 1613                     NaN                   7          2           medical
#
#      employee_number  environment_satisfaction gender hourly_rate  \
# 0                162                         1      M          51
# 1                259                         3      M          65
# 2                319                         3      M          58
# 3               None                         1      F          82
# 4               None                         1      F          45
# ...              ...                       ...    ...         ...
# 1609             967                         3      M          51
# 1610             972                         3      M          57
# 1611            None                        13      M          41
# 1612             990                         1      M          84
# 1613            None                         4      M          75
#
#       job_involvement  job_level                job_role  job_satisfaction  \
# 0                   3          5       research director                 3
# 1                   2          5                 manager                 3
# 2                   3          5                 manager                 4
# 3                   3          4       research director                 3
# 4                   4          4         sales executive                 1
# ...               ...        ...                     ...               ...
# 1609                2          3         sales executive                 4
# 1610                3          2   laboratory technician                 2
# 1611                4          3         sales executive                 3
# 1612                3          2         sales executive                 4
# 1613                3          3  manufacturing director                 3
#
#      marital_status monthly_income  monthly_rate  num_companies_worked over18  \
# 0               NaN          19537          6462                     7   True
# 1               NaN          19999          5678                     0    NaN
# 2           married          19232          4933                     1    NaN
# 3           married          17169         26703                     3   True
# 4          divorced           None          7739                     2   True
# ...             ...            ...           ...                   ...    ...
# 1609        married          10325          5518                     1   True
# 1610            NaN           4447         23163                     1    NaN
# 1611         single           None          2560                     0    NaN
# 1612       divorced           None         25952                     4    NaN
# 1613            NaN          10845         24208                     6   True
#
#      over_time  percent_salary_hike performance_rating  \
# 0        False                 0.13                  3
# 1          NaN                 0.14                  3
# 2        False                 0.11                  3
# 3          NaN                 0.19                  3
# 4        False                 0.12                  3
# ...        ...                  ...                ...
# 1609       NaN                 0.11               None
# 1610       NaN                 0.12                  3
# 1611     False                 0.18                  3
# 1612     False                 0.13               None
# 1613       NaN                 0.13                  3
#
#       relationship_satisfaction standard_hours  stock_option_level  \
# 0                             3           None                   0
# 1                             1           None                   1
# 2                             4           None                   0
# 3                             2           None                   2
# 4                             4           None                   1
# ...                         ...            ...                 ...
# 1609                          1           None                   1
# 1610                          2           None                   0
# 1611                          4           None                   0
# 1612                          4           None                   2
# 1613                          2           None                   1
#
#      total_working_years  training_times_last_year  work_life_balance  \
# 0                   None                         5                  3
# 1                     34                         5                  3
# 2                     22                         3              99999
# 3                   None                         2              99999
# 4                   None                         5                  3
# ...                  ...                       ...                ...
# 1609                None                         6                  3
# 1610                None                         5                  2
# 1611                   9                         3                  3
# 1612                  12                         3                  3
# 1613                None                         3                  3
#
#       years_at_company years_in_current_role  years_since_last_promotion  \
# 0                   20                  None                          15
# 1                   33                  None                          11
# 2                   22                  None                          11
# 3                   20                  None                           5
# 4                   19                  None                           2
# ...                ...                   ...                         ...
# 1609                16                  None                           3
# 1610                 9                  None                           0
# 1611                 8                  None                           0
# 1612                 7                  None                           0
# 1613                 8                  None                           0
#
#       years_with_curr_manager same_as_monthly_income  date_birth      salary  \
# 0                          15                  19537        1972  1000000000
# 1                           9                  19999        1971  1000000000
# 2                          15                  19232        1981  1000000000
# 3                           6                  17169        1976  1000000000
# 4                           8                   None        1977  1000000000
# ...                       ...                    ...         ...         ...
# 1609                        7                  10325        1987  1000000000
# 1610                        8                   4447        1978  1000000000
# 1611                        7                   None        1984  1000000000
# 1612                        7                   None        1987  1000000000
# 1613                        7                  10845        1977  1000000000
#
#             role_departament remote_work
# 0                        nan        True
# 1                        nan           1
# 2     research & development           1
# 3                        nan       False
# 4                        nan       False
# ...                      ...         ...
# 1609                     nan       False
# 1610                     nan           1
# 1611                     nan        True
# 1612                     nan        True
# 1613                     nan       False
#
# [1614 rows x 40 columns]

# %% [markdown]
# - cambiar NaN (o nan) por None ------JOHANNA

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_384\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('HR RAW DATA.csv')

df
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df.loc[df.employeecount != 1]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, employeecount, employeenumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NUMCOMPANIESWORKED, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TOTALWORKINGYEARS, TrainingTimesLastYear, WORKLIFEBALANCE, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YEARSWITHCURRMANAGER, SameAsMonthlyIncome, DateBirth, Salary, RoleDepartament, NUMBERCHILDREN, RemoteWork]
# Index: []
#
# [0 rows x 42 columns]

# %%
df_inspec = df.iloc[:, 11:20]

# %%
df_inspec.sample(10)
# Out:
#       EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 449                         3       1         51               3         2
# 400                         4       1         38               3         2
# 206                         3       0         42               2         3
# 956                         1       1         78               2         3
# 793                         3       1         98               3         1
# 1509                        3       0         83               3         3
# 310                         2       0         77               1         1
# 1497                        1       1         83               3         1
# 1314                        3       1         71               3         1
# 965                         4       1         33               3         2
#
#                           JobRole  JobSatisfaction MaritalStatus MonthlyIncome
# ...

# %%
df_inspec.dtypes
# Out:
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                 object
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome              object
# dtype: object

# %%
df.iloc[:, 31:42]
# Out:
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 0                3,0              20                NaN
# 1                3,0              33                NaN
# 2                NaN              22                NaN
# 3                NaN              20                NaN
# 4                3,0              19                NaN
# ...              ...             ...                ...
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1611             3,0               8                NaN
# 1612             3,0               7                NaN
# 1613             3,0               8                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 0                          15                    15             19537,0
# 1                          11                     9             19999,0
# 2                          11                    15             19232,0
# ...

# %% [markdown]
# - unificar títulos de columnas
# - porcentajes float/integer
# - unificar strings en title
# - las cuantías que sean string pasarlas a float/integer
# - yes/no unificar >> True/False
# - RemoteWork unificar a yes/no >> True/False
# - comprobar si hay números negativos

# %% [markdown]
# ines:
#
# - Age(object) --- age(int64)
# - Attrition(object) ----- attrition(booleano)
# - BussinessTravel(object) ------ bussiness_travel(object)
# - DailyRate(object) -------- daily_rate(float) (quitar el símbolo de la moneda) (mirar a ver si hay algún minus)
# - Department(object) ---------department(object)
# - DistanceFromHome(int64) --------distance_from_home(int64) (hay algún minus)
# - Education(int64) --------- education(int64)
# - EducationField(object) ------- education_field(object)
# - employeecount  --- son todos 1?
# - employeenumber(object) ---------employee_number(int)

# %% [markdown]
# mirna:
# - empresas: int
# - +18 = true/false
# - overtime = true/false
# - % = float (/100)
# - calificacion rendimiento = int / nan
# - standard hours = int / nan
# - stock_op = int
# - total_working = int/nan
# - training = int

# %% [markdown]
# johanna:
#
# - YearsAtCompany               int64
# - YearsInCurrentRole          object - NaN / Float
# - YearsSinceLastPromotion      int64
# - YEARSWITHCURRMANAGER         int64
# - SameAsMonthlyIncome         object - NaN /Float
# - DateBirth                    int64
# - Salary                      object - Dolar $  - Cambio
# - RoleDepartament             object
# - NUMBERCHILDREN             float64 - NaN
# - RemoteWork                  object -  True/ False

# %% [markdown]
# # HACER COSAS

# %% [markdown]
# - Satisfaction: intuyo que es una escala 1-100??? --- int
#
# - Gender: 0 - 1 > pasar a M, F --- int
#
# - HourlyRate: tarifa por hora --- object
#     - "Not Available" = cambiar por NaN
#
# - JobInvolvement: intuyo que escala 1-5 ---int [COMPROBAR]
#
# - JobLevel: nivel jerárquico --- int
#
# - JobRole: hay que arreglar estos strings --- objetc
#
# - JobSatisfaction: escala 1-5 --- int [COMPROBAR]
#
# - MaritalStatus: Married, Divorced, Single, NaN --- object
#
# - MonthlyIncome: float --- object (cambiar coma por punto)

# %%
df_inspec['MaritalStatus']
# Out:
# 0            NaN
# 1            NaN
# 2        married
# 3        married
# 4       divorced
#           ...
# 1609     married
# 1610         NaN
# 1611      single
# 1612    divorced
# 1613         NaN
# Name: MaritalStatus, Length: 1614, dtype: object

# %% [markdown]
# # COSAS HECHAS:

# %%
df_inspec['MaritalStatus'] = df_inspec['MaritalStatus'].str.lower()

# %%
df_inspec['Gender'] = df_inspec['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df_inspec['HourlyRate'] = df_inspec['HourlyRate'].replace('Not Available', np.nan)

# %%
print(min(df_inspec['JobSatisfaction']))
print(max(df_inspec['JobSatisfaction']))
# Out:
# 1
# 4

# %%
print(min(df_inspec['JobLevel']))
print(max(df_inspec['JobLevel']))
# Out:
# 1
# 5

# %%
print(min(df_inspec['JobInvolvement']))
print(max(df_inspec['JobInvolvement']))
# Out:
# 1
# 4

# %% [markdown]
# # COMPROBACIONES (OTRAS)

# %%
df
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
for elemento in df.StandardHours:
    if type(elemento) == str:
        df.StandardHours = df.StandardHours.replace(',', '.').astype(float)

# %%
df.StandardHours
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1609   NaN
# 1610   NaN
# 1611   NaN
# 1612   NaN
# 1613   NaN
# Name: StandardHours, Length: 1614, dtype: float64

# %% [markdown]
# ines:
#
# - Age(object) --- age(int64)
# - Attrition(object) ----- attrition(booleano)
# - BussinessTravel(object) ------ bussiness_travel(object)
# - DailyRate(object) -------- daily_rate(float) (quitar el símbolo de la moneda) (mirar a ver si hay algún minus)
# - Department(object) ---------department(object)
# - DistanceFromHome(int64) --------distance_from_home(int64) (hay algún minus)
# - Education(int64) --------- education(int64)
# - EducationField(object) ------- education_field(object)
# - employeecount  --- son todos 1?
# - employeenumber(object) ---------employee_number(int)

# %%
df.employeenumber = df.employeenumber.str.replace(',', '.').astype(float)

# %%
df.EducationField =  df.EducationField.str.lower()

# %%
df.DistanceFromHome = df.DistanceFromHome.replace('-','')

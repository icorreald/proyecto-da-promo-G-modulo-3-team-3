# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_8536\2872363843.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../csv-archivos/HR RAW DATA.csv', index_col=0)

df
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
df.iloc[:, 11:20]
# Out:
#       Gender HourlyRate  JobInvolvement  JobLevel                   JobRole  \
# 0          0         51               3         5        resEArch DIREcToR
# 1          0         65               2         5                  ManAGeR
# 2          0         58               3         5                  ManaGER
# 3          1         82               3         4        ReseArCH DIrECtOr
# 4          1         45               4         4          sAleS EXECUtIve
# ...      ...        ...             ...       ...                       ...
# 1609       0         51               2         3          saLEs ExeCUTiVe
# 1610       0         57               3         2    LAboRaTOry tECHNiCIAn
# 1611       0         41               4         3          sAlES ExECUTivE
# 1612       0         84               3         2          SaLes ExecUtIVe
# 1613       0         75               3         3   mAnUfactURInG DiRECTOr
#
#       JobSatisfaction MaritalStatus MonthlyIncome  MonthlyRate
# ...

# %%
df_inspec = df.iloc[:, 10:20]

# %%
df_inspec.dtypes
# Out:
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                 object
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome              object
# MonthlyRate                 int64
# dtype: object

# %% [markdown]
# - unificar títulos de columnas
# - porcentajes float/integer
# - unificar strings en title
# - las cuantías que sean string pasarlas a float/integer
# - yes/no unificar >> True/False
# - RemoteWork unificar a yes/no >> True/False
# - comprobar si hay números negativos

# %% [markdown]
# ## OBSERVACIONES INDIVIDUALES
# ines:
#
# - Age(object) --- age(int64)
# - Attrition(object) ----- attrition(booleano)
# - BussinessTravel(object) ------ bussiness_travel(object)
# - DailyRate(object) -------- daily_rate(float) (quitar el símbolo de la moneda) (mirar a ver si hay algún minus)
# - Department(object) ---------department(object)
# - DistanceFromHome(int64) --------distance_from_home(int64) (hay algún minus)
# - Education(int64) --------- education(int64)
# - EducationField(object) ------- education_field(object)
# - employeecount  --- son todos 1?
# - employeenumber(object) ---------employee_number(int)
#
#
# mirna:
# - empresas: int
# - +18 = true/false
# - overtime = true/false
# - % = float (/100)
# - calificacion rendimiento = int / nan
# - standard hours = int / nan
# - stock_op = int
# - total_working = int/nan
# - training = int
#
#
# johanna:
# - YearsAtCompany               int64
# - YearsInCurrentRole          object - NaN / Float
# - YearsSinceLastPromotion      int64
# - YEARSWITHCURRMANAGER         int64
# - SameAsMonthlyIncome         object - NaN /Float
# - DateBirth                    int64
# - Salary                      object - Dolar $  - Cambio
# - RoleDepartament             object
# - NUMBERCHILDREN             float64 - NaN
# - RemoteWork                  object -  True/ False
#
#
# isa:
# - Satisfaction: intuyo que es una escala 1-100??? --- int
# - Gender: 0 - 1 > pasar a M, F --- int
# - HourlyRate: tarifa por hora --- object
#     - "Not Available" = cambiar por NaN
# - JobInvolvement: intuyo que escala 1-5 ---int [COMPROBAR]
# - JobLevel: nivel jerárquico --- int
# - JobRole: hay que arreglar estos strings --- objetc
# - JobSatisfaction: escala 1-5 --- int [COMPROBAR]
# - MaritalStatus: Married, Divorced, Single, NaN --- object
# - MonthlyIncome: float --- object (cambiar coma por punto)

# %% [markdown]
# ## CODIGOS

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
df_inspec.head()
# Out:
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
# 1                        3       0         65               2         5
# 2                        3       0         58               3         5
# 3                        1       1         82               3         4
# 4                        1       1         45               4         4
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
# 2             ManaGER                 4       Married       19232,0
# 3   ReseArCH DIrECtOr                 3       Married       17169,0
# 4     sAleS EXECUtIve                 1      Divorced           NaN

# %%
for columna in df_inspec:
    print(f'-------COLUMNA: {columna}-------\n')
    print('VALORES ÚNICOS:\n', df_inspec[columna].unique(), '\n')
# Out:
# -------COLUMNA: EnvironmentSatisfaction-------
#
# VALORES ÚNICOS:
#  [ 1  3  4  2 42 37 35 25 27 31 39 21 15 14 33 19 12 13 28 47 36 29 24 46
#  16 22 41 49 11 48 18 10 45 38 17 20 26 43]
#
# -------COLUMNA: Gender-------
#
# VALORES ÚNICOS:
#  [0 1]
#
# -------COLUMNA: HourlyRate-------
#
# VALORES ÚNICOS:
#  ['51' '65' '58' '82' '45' '99' '91' '64' '55' '68' '49' '61' '79' '31'
#  '69' '48' '80' '74' '98' '59' '33' '56' '66' '57' '53' '87' '81' '84'
#  '32' '41' '92' '47' 'Not Available' '43' '86' '30' '42' '88' '96' '67'
#  '62' '72' '78' '89' '52' '50' '90' '37' '94' '76' '60' '46' '83' '100'
#  '40' '97' '54' '75' '39' '85' '63' '44' '93' '36' '35' '73' '71' '70'
#  '38' '77' '95' '34']
#
# -------COLUMNA: JobInvolvement-------
#
# VALORES ÚNICOS:
#  [3 2 4 1]
#
# -------COLUMNA: JobLevel-------
#
# VALORES ÚNICOS:
#  [5 4 3 2 1]
#
# -------COLUMNA: JobRole-------
#
# VALORES ÚNICOS:
#  [' resEArch DIREcToR ' ' ManAGeR ' ' ManaGER ' ... ' sAlES ExECUTivE '
# ...

# %%
df_inspec['MonthlyIncome']
# Out:
# 0       19537,0
# 1       19999,0
# 2       19232,0
# 3       17169,0
# 4           NaN
#          ...
# 1609    10325,0
# 1610     4447,0
# 1611        NaN
# 1612        NaN
# 1613    10845,0
# Name: MonthlyIncome, Length: 1614, dtype: object

# %%
df['WORKLIFEBALANCE'] = df['WORKLIFEBALANCE'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['DailyRate'] = df['DailyRate'].str.replace(',', '.').str.replace('$', '').astype(float).fillna(99999).astype(int)

# %%
df['DailyRate']
# Out:
# 0        684
# 1        699
# 2        532
# 3        359
# 4       1319
#         ...
# 1609     530
# 1610     805
# 1611     903
# 1612    1229
# 1613     566
# Name: DailyRate, Length: 1614, dtype: int32

# %%
df['WORKLIFEBALANCE']
# Out:
# 0           3
# 1           3
# 2       99999
# 3       99999
# 4           3
#         ...
# 1609        3
# 1610        2
# 1611        3
# 1612        3
# 1613        3
# Name: WORKLIFEBALANCE, Length: 1614, dtype: int32

# %% [markdown]
# ## COSAS HECHAS:

# %%
# nombres columnas
columnas = df.columns.tolist()
columnas = columnas[1:]
columnas
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'employeecount',
#  'employeenumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NUMCOMPANIESWORKED',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TOTALWORKINGYEARS',
#  'TrainingTimesLastYear',
#  'WORKLIFEBALANCE',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YEARSWITHCURRMANAGER',
#  'SameAsMonthlyIncome',
#  'DateBirth',
#  'Salary',
#  'RoleDepartament',
#  'NUMBERCHILDREN',
#  'RemoteWork']

# %%
import re

# %%
patron_may_min = re.compile(r'([a-z])([A-Z])')
patron_employee = re.compile(r'(employee)(\w)')

columnas_2 = []

for nombre in columnas:
    if patron_may_min.search(nombre):
        nombre = patron_may_min.sub(r'\1_\2', nombre)
        columnas_2.append(nombre.lower())

    elif patron_employee.search(nombre):
        nombre = patron_employee.sub(r'\1_\2', nombre)
        columnas_2.append(nombre)

    elif nombre == 'NUMCOMPANIESWORKED':
        nombre = 'num_companies_worked'
        columnas_2.append(nombre)

    elif nombre == 'Over18':
        nombre = 'over_18'
        columnas_2.append(nombre)

    else:
        columnas_2.append(nombre.lower())

columnas_2
# Out:
# ['attrition',
#  'business_travel',
#  'daily_rate',
#  'department',
#  'distance_from_home',
#  'education',
#  'education_field',
#  'employee_count',
#  'employee_number',
#  'environment_satisfaction',
#  'gender',
#  'hourly_rate',
#  'job_involvement',
#  'job_level',
#  'job_role',
#  'job_satisfaction',
#  'marital_status',
#  'monthly_income',
#  'monthly_rate',
#  'num_companies_worked',
#  'over_18',
#  'over_time',
#  'percent_salary_hike',
#  'performance_rating',
#  'relationship_satisfaction',
#  'standard_hours',
#  'stock_option_level',
#  'totalworkingyears',
#  'training_times_last_year',
#  'worklifebalance',
#  'years_at_company',
#  'years_in_current_role',
#  'years_since_last_promotion',
#  'yearswithcurrmanager',
#  'same_as_monthly_income',
#  'date_birth',
#  'salary',
#  'role_departament',
#  'numberchildren',
#  'remote_work']

# %%
print(len(columnas))
print(len(columnas_2))
# Out:
# 41
# 27

# %%
serie_columnas
# Out:
# 0                          Age
# 1                    Attrition
# 2               BusinessTravel
# 3                    DailyRate
# 4                   Department
# 5             DistanceFromHome
# 6                    Education
# 7               EducationField
# 8                employeecount
# 9               employeenumber
# 10     EnvironmentSatisfaction
# 11                      Gender
# 12                  HourlyRate
# 13              JobInvolvement
# 14                    JobLevel
# 15                     JobRole
# 16             JobSatisfaction
# 17               MaritalStatus
# 18               MonthlyIncome
# 19                 MonthlyRate
# 20          NUMCOMPANIESWORKED
# 21                      Over18
# 22                    OverTime
# 23           PercentSalaryHike
# 24           PerformanceRating
# 25    RelationshipSatisfaction
# 26               StandardHours
# 27            StockOptionLevel
# 28           TOTALWORKINGYEARS
# 29       TrainingTimesLastYear
# ...

# %%
df_inspec['MonthlyIncome'] = df_inspec['MonthlyIncome'].str.replace(',', '.').astype(float).fillna(0).astype(int)

# %%
df_inspec['JobRole'] = df_inspec['JobRole'].str.lower().str.strip()

# %%
df_inspec['MaritalStatus'] = df_inspec['MaritalStatus'].str.lower().str.strip()

# %%
df_inspec['MaritalStatus'] = df_inspec['MaritalStatus'].str.replace('marreid', 'married')

# %%
df_inspec['Gender'] = df_inspec['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df_inspec['HourlyRate'] = df_inspec['HourlyRate'].replace('Not Available', np.nan)

# %% [markdown]
# # COMPROBACIONES (OTRAS)

# %%
df_inspec['MonthlyIncome'].sample(10)
# Out:
# 1417     1569.0
# 650         NaN
# 516      3211.0
# 193      5674.0
# 557     12936.0
# 1438        NaN
# 1068        NaN
# 1421     3306.0
# 315         NaN
# 332      9434.0
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# # estudio columnas 'personal'

# %%
import numpy as np
import pandas as pd
import re

pd.set_option('display.max_columns', None)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_11400\1016511574.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../csv-archivos/datos_limpios.csv')

df.head()
# Out:
#    Unnamed: 0   age  attrition business_travel  daily_rate  \
# 0           0  51.0      False             NaN       684.0
# 1           1  52.0      False             NaN       699.0
# 2           2  42.0      False          rarely       532.0
# 3           3  47.0      False          rarely       359.0
# 4           4  46.0      False             NaN      1319.0
#
#                department  distance_from_home  education   education_field  \
# 0                     NaN                   6          3               NaN
# 1                     NaN                   1          4     life sciences
# 2  research & development                   4          2  technical degree
# 3                     NaN                   2          4           medical
# 4                     NaN                   3          3  technical degree
#
#    employee_number  environment_satisfaction gender  hourly_rate  \
# 0            162.0                         1      m         51.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'attrition', 'business_travel', 'daily_rate',
#        'department', 'distance_from_home', 'education', 'education_field',
#        'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_income', 'monthly_rate',
#        'num_companies_worked', 'over18', 'over_time', 'percent_salary_hike',
#        'performance_rating', 'relationship_satisfaction', 'standard_hours',
#        'stock_option_level', 'total_working_years', 'training_times_last_year',
#        'work_life_balance', 'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work'],
#       dtype='object')

# %%
personal = df[['age', 'date_birth', 'over18', 'gender', 'distance_from_home', 'education', 'education_field', 'marital_status']]

# %%
personal.shape
# Out:
# (1614, 8)

# %%
personal.head()
# Out:
#     age  date_birth over18 gender  distance_from_home  education  \
# 0  51.0        1972   True      m                   6          3
# 1  52.0        1971    NaN      m                   1          4
# 2  42.0        1981    NaN      m                   4          2
# 3  47.0        1976   True      f                   2          4
# 4  46.0        1977   True      f                   3          3
#
#     education_field marital_status
# 0               NaN            NaN
# 1     life sciences            NaN
# 2  technical degree        married
# 3           medical        married
# 4  technical degree       divorced

# %%
personal[(personal['age'].isna()) & (personal['date_birth'] > 0)]
# Out:
#       age  date_birth over18 gender  distance_from_home  education  \
# 31    NaN        1976    NaN      m                  25          3
# 79    NaN        1965    NaN      m                  18          4
# 216   NaN        1987   True      f                  12          5
# 357   NaN        1968   True      m                   2          1
# 411   NaN        1971   True      m                   5          3
# 426   NaN        1992    NaN      m                   8          2
# 593   NaN        1993    NaN      f                   2          3
# 1198  NaN        1997   True      m                  21          3
# 1226  NaN        1986    NaN      m                   2          2
# 1293  NaN        1986   True      m                  10          4
# 1325  NaN        1999   True      m                   9          3
# 1584  NaN        1991    NaN      f                   3          2
#
#      education_field marital_status
# 31           medical            NaN
# ...

# %%
personal['age'].isnull().sum()
# Out:
# 0

# %%
df['age'].head()
# Out:
# 0    51.0
# 1    52.0
# 2    42.0
# 3    47.0
# 4    46.0
# Name: age, dtype: float64

# %%
personal
# Out:
#       age  date_birth over18 gender  distance_from_home  education  \
# 0      51        1972   True      m                   6          3
# 1      52        1971    NaN      m                   1          4
# 2      42        1981    NaN      m                   4          2
# 3      47        1976   True      f                   2          4
# 4      46        1977   True      f                   3          3
# ...   ...         ...    ...    ...                 ...        ...
# 1609   36        1987   True      m                   3          1
# 1610   45        1978    NaN      m                   4          2
# 1611   39        1984    NaN      m                  13          5
# 1612   36        1987    NaN      m                   8          4
# 1613   46        1977   True      m                   7          2
#
#        education_field marital_status
# 0                  NaN            NaN
# 1        life sciences            NaN
# 2     technical degree        married
# ...

# %%
over_18 = personal[(personal['age'] >= 18) & (personal['over18'] == False)]

# %%
personal['over18']
# Out:
# 0       True
# 1        NaN
# 2        NaN
# 3       True
# 4       True
#         ...
# 1609    True
# 1610     NaN
# 1611     NaN
# 1612     NaN
# 1613    True
# Name: over18, Length: 1614, dtype: object

# %%
personal['over18'].unique()
# Out:
# array([True, nan], dtype=object)

# %% [markdown]
# # cambios realizados

# %% [markdown]
# - quitar edades nulas (2023 - date_birth) --- no hay date_birth nulos

# %% [markdown]
# - quitar nulos de over18 (ya tenemos las edades)

# %% [markdown]
# # COMPROBACIONES

# %%
df_sucio = pd.read_csv('../csv-archivos/HR RAW DATA.csv')

# %%
df_sucio['Over18'].unique()
# Out:
# array(['Y', nan], dtype=object)

# %%
df = pd.read_csv('../csv-archivos/datos_limpios.csv', index_col=0)

# %%
df['employee_number'].unique()
# Out:
# array([ 162.,  259.,  319., ..., 2012., 2023., 2040.])

# %%
df.head()
# Out:
#     age  attrition business_travel  daily_rate              department  \
# 0  51.0      False             NaN       684.0                     NaN
# 1  52.0      False             NaN       699.0                     NaN
# 2  42.0      False          rarely       532.0  research & development
# 3  47.0      False          rarely       359.0                     NaN
# 4  46.0      False             NaN      1319.0                     NaN
#
#    distance_from_home  education   education_field  employee_number  \
# 0                   6          3               NaN            162.0
# 1                   1          4     life sciences            259.0
# 2                   4          2  technical degree            319.0
# 3                   2          4           medical              NaN
# 4                   3          3  technical degree              NaN
#
#    environment_satisfaction gender  hourly_rate  job_involvement  job_level  \
# ...

# %%
print('Nulos:',df['employee_number'].isnull().sum()/df.shape[0]*100)
# Out:
# Nulos: 26.703841387856258

# %%
print('Duplicados:',df['employee_number'].duplicated().sum()/df['employee_number'].shape[0]*100)
# Out:
# Duplicados: 33.08550185873606

# %%
df['employee_number'].value_counts()
# Out:
# employee_number
# 482.0     2
# 530.0     2
# 507.0     2
# 517.0     2
# 522.0     2
#          ..
# 161.0     1
# 164.0     1
# 190.0     1
# 194.0     1
# 2040.0    1
# Name: count, Length: 1079, dtype: int64

# %%
duplicados = df[df.duplicated()]

# %%
df[df['employee_number']==307]
# Out:
#        age  attrition business_travel  daily_rate department  \
# 82    38.0      False             NaN       119.0        NaN
# 1474  38.0      False             NaN       119.0        NaN
#
#       distance_from_home  education education_field  employee_number  \
# 82                     3          3   life sciences            307.0
# 1474                   3          3   life sciences            307.0
#
#       environment_satisfaction gender  hourly_rate  job_involvement  \
# 82                           1      m         76.0                3
# 1474                         1      m         76.0                3
#
#       job_level         job_role  job_satisfaction marital_status  \
# 82            3  sales executive                 3       divorced
# 1474          3  sales executive                 3       divorced
#
#       monthly_income  monthly_rate  num_companies_worked over18 over_time  \
# 82               NaN          9647                     0   True       NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df['employee_number']==307]
# Out:
#      age  attrition business_travel  daily_rate department  \
# 82  38.0      False             NaN       119.0        NaN
#
#     distance_from_home  education education_field  employee_number  \
# 82                   3          3   life sciences            307.0
#
#     environment_satisfaction gender  hourly_rate  job_involvement  job_level  \
# 82                         1      m         76.0                3          3
#
#            job_role  job_satisfaction marital_status  monthly_income  \
# 82  sales executive                 3       divorced             NaN
#
#     monthly_rate  num_companies_worked over18 over_time  percent_salary_hike  \
# 82          9647                     0   True       NaN                 0.12
#
#     performance_rating  relationship_satisfaction  standard_hours  \
# 82                 3.0                          3             NaN
#
#     stock_option_level  total_working_years  training_times_last_year  \
# ...

# %%
df['employee_number'].duplicated().sum()/df['employee_number'].shape[0]*100
# Out:
# 31.645569620253166

# %%
df[df['employee_number'].duplicated()]
# Out:
#        age  attrition business_travel  daily_rate department  \
# 4     46.0      False             NaN      1319.0        NaN
# 8     41.0      False             NaN      1276.0        NaN
# 11    56.0      False          rarely      1369.0        NaN
# 12    38.0      False             NaN       201.0        NaN
# 14    55.0      False             NaN       692.0        NaN
# ...    ...        ...             ...         ...        ...
# 1608  32.0      False             NaN       498.0        NaN
# 1610  45.0      False              no       805.0        NaN
# 1611  39.0      False          rarely       903.0        NaN
# 1612  36.0      False              no      1229.0        NaN
# 1613  46.0      False             NaN       566.0        NaN
#
#       distance_from_home  education   education_field  employee_number  \
# 4                      3          3  technical degree              NaN
# 8                      2          5               NaN              NaN
# ...

# %%
df[df['employee_number']==972]
# Out:
#        age  attrition business_travel  daily_rate department  \
# 367   45.0      False              no       805.0        NaN
# 1610  45.0      False              no       805.0        NaN
#
#       distance_from_home  education education_field  employee_number  \
# 367                   47          2             NaN            972.0
# 1610                   4          2             NaN            972.0
#
#       environment_satisfaction gender  hourly_rate  job_involvement  \
# 367                         47      m         57.0                3
# 1610                         3      m         57.0                3
#
#       job_level               job_role  job_satisfaction marital_status  \
# 367           2  laboratory technician                 2            NaN
# 1610          2  laboratory technician                 2            NaN
#
#       monthly_income  monthly_rate  num_companies_worked over18 over_time  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over18',
#        'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work'],
#       dtype='object')

# %%
df.drop(columns = ['role_departament'], inplace=True)

# %%
nivel_correcto = [1, 2, 3, 4]
df['environment_satisfaction'] = df['environment_satisfaction'].apply(lambda x: x if x in nivel_correcto else np.nan)

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'date_birth', 'remote_work'],
#       dtype='object')

# %%
df.to_csv('limpieza_final.csv')

# %% [markdown]
# # COLUMNA currently_working

# %%
df = pd.read_csv('../csv-archivos/limpieza_final.csv')

# %%
df['employee_number'].max()
# Out:
# 2068.0

# %%
no_nulos = df[df['employee_number']]

# %% [markdown]
# # EMPLOYEENUMBER

# %%
df = pd.read_csv('../csv-archivos/datos_sql.csv',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('../csv-archivos/datos_sql.csv',index_col=0)
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    Unnamed: 0  attrition business_travel  daily_rate              department  \
# 0           0      False             NaN       684.0                     NaN
# 1           1      False             NaN       699.0                     NaN
# 2           2      False          rarely       532.0  research & development
# 5           5      False             NaN       117.0  research & development
# 6           6      False             NaN      1435.0                     NaN
#
#    distance_from_home  education   education_field  employee_number  \
# 0                   6          3               NaN            162.0
# 1                   1          4     life sciences            259.0
# 2                   4          2  technical degree            319.0
# 5                  22          3           medical           1900.0
# 6                  25          3     life sciences             81.0
#
#    environment_satisfaction gender  hourly_rate  job_involvement  job_level  \
# ...

# %%
df['work_life_balance']
# Out:
# 0       3.0
# 1       3.0
# 2       NaN
# 5       3.0
# 6       2.0
#        ...
# 1568    3.0
# 1569    3.0
# 1574    1.0
# 1577    3.0
# 1579    3.0
# Name: work_life_balance, Length: 1580, dtype: float64

# %%
df.drop(columns=['years_in_current_role'], axis=1, inplace=True)

# %%
df['employee_number']= df['employee_number'].astype(int)

# %%
df.to_csv('../csv-archivos/datos_sql.csv')

# %% [markdown]
# # SUBSETS

# %%
employees = df[['employee_number', 'gender', 'date_birth']]

# %%
employees.drop_duplicates(inplace=True)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_8536\1506232936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employees.drop_duplicates(inplace=True)

# %%
employee_datails = df[['employee_number', 'department', 'job_role', 'job_level', 'job_involvement', 'years_at_company', 'years_since_last_promotion', 'years_with_current_manager', 'training_times_last_year', 'remote_work', 'performance_rating', 'attrition', 'marital_status', 'distance_from_home', 'education', 'education_field', 'total_working_years', 'num_companies_worked']]

# %%
economics = df[['employee_number', 'monthly_income', 'hourly_rate', 'monthly_rate', 'daily_rate', 'percent_salary_hike', 'stock_option_level', 'business_travel', 'over_time']]

# %%
satisfaction = df[['employee_number', 'environment_satisfaction', 'job_satisfaction', 'relationship_satisfaction', 'work_life_balance']]

# %%
df.isnull().sum()/df.shape[0] * 100
# Out:
# attrition                      0.000000
# business_travel               47.658228
# daily_rate                     7.784810
# department                    81.329114
# distance_from_home             0.000000
# education                      0.000000
# education_field               46.392405
# employee_number                0.000000
# environment_satisfaction       6.329114
# gender                         0.000000
# hourly_rate                    5.316456
# job_involvement                0.000000
# job_level                      0.000000
# job_role                       0.000000
# job_satisfaction               0.000000
# marital_status                40.506329
# monthly_income                52.278481
# monthly_rate                   0.000000
# num_companies_worked           0.000000
# over_time                     41.962025
# percent_salary_hike            0.000000
# performance_rating            12.025316
# relationship_satisfaction      0.000000
# ...

# %%
employee_datails.to_csv('../csv-archivos/employee_details.csv')

# %%
economics.to_csv('../csv-archivos/economics.csv')

# %% [markdown]
# # GRAFICAS

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) 

from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_4040\827415198.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../csv-archivos/datos_sql.csv', index_col=0)

# %%
dfnum = df.select_dtypes(include=['int', 'float'])
dfcat = df.select_dtypes(exclude=['int', 'float'])

# %%
dfnum.columns
# Out:
# Index(['daily_rate', 'distance_from_home', 'education', 'employee_number',
#        'environment_satisfaction', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_satisfaction', 'monthly_income', 'monthly_rate',
#        'num_companies_worked', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth'],
#       dtype='object')

# %%
dfcat.columns
# Out:
# Index(['attrition', 'business_travel', 'department', 'education_field',
#        'gender', 'job_role', 'marital_status', 'over_time', 'remote_work'],
#       dtype='object')

# %%
from itertools import combinations
combinaciones = list(combinations(dfnum.columns, 2))

# %%
def identificar_linealidad (dataframe, lista_combinacion_columnas):
    """
    Identifica si las relaciones entre pares de variables en un DataFrame son lineales o no.

    Parameters:
    -----------
    dataframe : pandas.DataFrame
        El DataFrame que contiene las variables a analizar.

    lista_combinacion_columnas : list of tuples
        Una lista de tuplas donde cada tupla contiene dos nombres de columnas del DataFrame que se desea analizar.

    Returns:
    --------
    relaciones_lineales : list of tuples
        Una lista de tuplas que contienen los nombres de las columnas que tienen una relación lineal.

    relaciones_no_lineales : list of tuples
        Una lista de tuplas que contienen los nombres de las columnas que no tienen una relación lineal.

    """
    relaciones_lineales = []
    relaciones_no_lineales = []

    for tupla in lista_combinacion_columnas: 
        # Realizar la prueba de normalidad
        _, p_value1 = kstest(dataframe[tupla[0]], "norm")
        _, p_value2 = kstest(dataframe[tupla[1]], "norm")

        if p_value1 > 0.05 and p_value2 > 0.05:
            relaciones_lineales.append(tupla)
        else:
            relaciones_no_lineales.append(tupla)

    return relaciones_lineales, relaciones_no_lineales

# %%
lineal, no_lineal = identificar_linealidad(df, combinaciones)

print(f"Las variables a las que tengamos que aplicar la correlacion de pearson son: {lineal}")
print(f"Las variables a las que tengamos que aplicar la correlacion de spearman son: {no_lineal}")
# Out:
# Las variables a las que tengamos que aplicar la correlacion de pearson son: []
# ...

# %%
df_correlaciones = df.corr(numeric_only = True, method = "spearman")
df_correlaciones
# Out:
#                             attrition  daily_rate  distance_from_home  \
# attrition                    1.000000   -0.066228            0.049613
# daily_rate                  -0.066228    1.000000            0.011595
# distance_from_home           0.049613    0.011595            1.000000
# education                   -0.028303   -0.005186            0.006782
# employee_number             -0.008569   -0.015429            0.021861
# environment_satisfaction    -0.103197    0.015151           -0.015288
# hourly_rate                  0.010945    0.018882            0.014323
# job_involvement             -0.122943    0.052618            0.029364
# job_level                   -0.188661    0.012978            0.020300
# job_satisfaction            -0.102869    0.037767            0.005862
# monthly_income              -0.197975    0.006510           -0.050234
# monthly_rate                 0.007261   -0.031861            0.018115
# ...

# %%
mask = np.triu(np.ones_like(df_correlaciones, dtype=bool))

# %%
plt.figure(figsize = (15, 15))


# creamos un heatmap con la máscara
sns.heatmap(df_correlaciones, 
            annot = True, 
            fmt = ".2f", 
            cmap = "viridis", 
            vmax = 1, 
            vmin = -1);

# %%
sns.histplot(x = "work_life_balance", 
             data = df, 
             color = "teal", 
             kde = True, 
             bins = 20 )
# Out:
# <Axes: xlabel='work_life_balance', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work'],
#       dtype='object')

# %%
dfcat.columns
# Out:
# Index(['attrition', 'business_travel', 'department', 'education_field',
#        'gender', 'job_role', 'marital_status', 'over_time', 'remote_work'],
#       dtype='object')

# %%
sns.barplot(x = "marital_status", 
            y = "job_satisfaction", 
            data = df,
            palette = "viridis")
# Out:
# <Axes: xlabel='marital_status', ylabel='job_satisfaction'>

# %%
df_attrition = df[['employee_number', 'attrition', 'job_satisfaction']]

df_attrition
# Out:
#       employee_number  attrition  job_satisfaction
# 0               162.0      False                 3
# 1               259.0      False                 3
# 2               319.0      False                 4
# 3                 NaN      False                 3
# 4                 NaN      False                 1
# ...               ...        ...               ...
# 1608            966.0      False                 1
# 1610            972.0      False                 2
# 1611              NaN      False                 3
# 1612            990.0      False                 4
# 1613              NaN      False                 3
#
# [1579 rows x 3 columns]

# %%
sns.countplot(x = "attrition", 
            data = df,
            palette = "viridis")
# Out:
# <Axes: xlabel='attrition', ylabel='count'>

# %% [markdown]
# # arreglar subsets

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_1524\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_og = pd.read_csv('../csv-archivos/HR RAW DATA.csv')

# %%
df_og['MaritalStatus'].head()
# Out:
# 0         NaN
# 1         NaN
# 2     Married
# 3     Married
# 4    Divorced
# Name: MaritalStatus, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'employee_number', 'department', 'job_role', 'job_level',
#        'job_involvement', 'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'training_times_last_year', 'remote_work',
#        'performance_rating', 'attrition', 'marital_status',
#        'distance_from_home', 'education', 'education_field',
#        'total_working_years', 'num_companies_worked'],
#       dtype='object')

# %%
df['marital_status'].unique()
# Out:
# array([nan, 'married', 'single', 'divorced', 'marreid'], dtype=object)

# %%
df['marital_status'] = df['marital_status'].replace('marreid', 'married')

# %%
df.to_csv('../csv-archivos/employee_details.csv')

# %% [markdown]
# # ab testing

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_14332\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../csv-archivos/datos_sql.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work', 'grupo'],
#       dtype='object')

# %%
grupo_a = df[df['job_satisfaction'] >=3]

grupo_b = df[df['job_satisfaction'] < 3]

print('A:', grupo_a.shape, 'B:', grupo_b.shape)
# Out:
# A: (968, 32) B: (611, 32)

# %%
grupo_a.to_csv('../csv-archivos/A_test.csv')
grupo_b.to_csv('../csv-archivos/B_test.csv')

# %%
df['grupo'] = df['job_satisfaction'].apply(lambda valor : 'control' if valor >= 3 else 'variante')

# %%
df.head()
# Out:
#    attrition business_travel  daily_rate              department  \
# 0      False             NaN       684.0                     NaN
# 1      False             NaN       699.0                     NaN
# 2      False          rarely       532.0  research & development
# 3      False          rarely       359.0                     NaN
# 4      False             NaN      1319.0                     NaN
#
#    distance_from_home  education   education_field  employee_number  \
# 0                   6          3               NaN            162.0
# 1                   1          4     life sciences            259.0
# 2                   4          2  technical degree            319.0
# 3                   2          4           medical              NaN
# 4                   3          3  technical degree              NaN
#
#    environment_satisfaction gender  ...  stock_option_level  \
# 0                       1.0      m  ...                   0
# ...

# %%
df.to_csv('../csv-archivos/datos_sql.csv')

# %%
tabla_cont = pd.crosstab(df['attrition'], df['grupo'])

tabla_cont
# Out:
# grupo      control  variante
# attrition
# False          835       489
# True           133       122

# %%
from scipy.stats import chi2_contingency

# %%
chi2, p_value, _, _ = chi2_contingency(tabla_cont)

# %%
p_value
# Out:
# 0.0013500147176510643

# %% [markdown]
# Rechazamos H0; por lo tanto, existe una diferencia entre ambos grupos con respecto al attrition (la satisfacción afecta a la rotación de empleados)

# %%
# porcentaje de empleados q dejaron la empresa
    # subplots
    # grafico x grupo

# %% [markdown]
# # analisis ab testing

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_4508\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../csv-archivos/datos_sql.csv', index_col=0)

# %%
satisfaction = []
for linea in df.columns:
    if 'satisfaction' in linea:
        satisfaction.append(linea)

satisfaction
# Out:
# ['environment_satisfaction', 'job_satisfaction', 'relationship_satisfaction']

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import kruskal
from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway
from sklearn.linear_model import LinearRegression

def normalidad(df, col):
 
    statistic, p_value = stats.shapiro(df[col])
    if p_value > 0.05:
        print(f"Para la columna {col} los datos siguen una distribución normal.")
    else:
        print(f"Para la columna {col} los datos no siguen una distribución normal.")

def homogeneidad (dataframe, columna, columna_metrica):
    
    
    # lo primero que tenemos que hacer es crear tantos conjuntos de datos para cada una de las categorías que tenemos, Control Campaign y Test Campaign
    valores_evaluar = []
    
    for valor in dataframe[columna].unique():
        valores_evaluar.append(dataframe[dataframe[columna]== valor][columna_metrica])

    statistic, p_value = stats.levene(*valores_evaluar)
    if p_value > 0.05:
        print(f"Para la métrica {columna_metrica} las varianzas son homogéneas entre grupos.")
    else:
        print(f"Para la métrica {columna_metrica} las varianzas no son homogéneas entre grupos.")


def test_man_whitney(dataframe, columnas_metricas, grupo_control, grupo_test, columna_grupos = "campaign_name"):

    
    # filtramos el DataFrame para quedarnos solo con los datos de control
    control = dataframe[dataframe[columna_grupos] == grupo_control]
    
    # filtramos el DataFrame para quedarnos solo con los datos de control
    test = dataframe[dataframe[columna_grupos] == grupo_test]
    
    
    # iteramos por las columnas de las metricas para ver si para cada una de ellas hay diferencias entre los grupos
    for metrica in columnas_metricas:
        
        # filtrams el conjunto de datos para quedarnos solo con la columna de la metrica que nos interesa
        metrica_control = control[metrica]
        metrica_test = test[metrica]
        
        # aplicamos el estadístico
        u_statistic, p_value = stats.mannwhitneyu(metrica_control, metrica_test)
        
        if p_value < 0.05:
            print(f"Para la métrica {metrica} las medianas son diferentes.")
        else:
            print(f"Para la métrica {metrica} las medianas son iguales.")
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_13008\3505178894.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# satisfaction (grupo control y variante):
# - attrition
# - over_time
# - salary_hike
#
# **NOTAS**:
# - la mayor diferencia en medias de satisfacción esta en **job_satisfaction**, por la que hemos hecho el corte para grupos. El ambiente y las relaciones interpersonales es mediocre, pero consistentes

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work', 'grupo'],
#       dtype='object')

# %%
df_medias = df.groupby('grupo')[['environment_satisfaction', 'job_satisfaction', 'relationship_satisfaction']].mean()
df_medias
# Out:
#           environment_satisfaction  job_satisfaction  \
# grupo
# control                   2.713971          3.515496
# variante                  2.726316          1.494272
#
#           relationship_satisfaction
# grupo
# control                    2.699380
# variante                   2.728314

# %%
df2 = df[['environment_satisfaction', 'job_satisfaction', 'relationship_satisfaction', 'attrition']]
df2['grupo'] = df['job_satisfaction'].apply(lambda x : 'variante' if x >= 3 else 'control')
df2.head()
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_13008\3779701899.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['grupo'] = df['job_satisfaction'].apply(lambda x : 'variante' if x >= 3 else 'control')
#    environment_satisfaction  job_satisfaction  relationship_satisfaction  \
# 0                       1.0                 3                          3
# 1                       3.0                 3                          1
# 2                       3.0                 4                          4
# 3                       1.0                 3                          2
# 4                       1.0                 1                          4
#
#    attrition     grupo
# 0      False  variante
# 1      False  variante
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='job_satisfaction', hue='attrition', data=df2)
# Out:
# <Axes: xlabel='job_satisfaction', ylabel='count'>

# %%
sns.countplot(x = df2[df2['attrition']==True]['grupo'], 
              data = df2)
# Out:
# <Axes: xlabel='grupo', ylabel='count'>

# %%
for columna in df2.columns[:3]:
    normalidad(df, columna)
    homogeneidad(df, 'grupo', columna)
    print('-'*20)
# Out:
# Para la columna environment_satisfaction los datos siguen una distribución normal.
# Para la métrica environment_satisfaction las varianzas no son homogéneas entre grupos.
# --------------------
# Para la columna job_satisfaction los datos no siguen una distribución normal.
# Para la métrica job_satisfaction las varianzas son homogéneas entre grupos.
# --------------------
# Para la columna relationship_satisfaction los datos no siguen una distribución normal.
# Para la métrica relationship_satisfaction las varianzas son homogéneas entre grupos.
# --------------------

# %%
test_man_whitney(df2, ['environment_satisfaction', 'job_satisfaction', 'relationship_satisfaction'], 'control', 'variante', 'grupo')
# Out:
# Para la métrica environment_satisfaction las medianas son iguales.
# Para la métrica job_satisfaction las medianas son diferentes.
# Para la métrica relationship_satisfaction las medianas son iguales.

# %%
df3 = df[['job_satisfaction', 'performance_rating', 'total_working_years','percent_salary_hike', 'attrition']]
df3['grupo'] = df3['job_satisfaction'].apply(lambda x : 'variante' if x >= 3 else 'control')
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_13008\2904809243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['grupo'] = df3['job_satisfaction'].apply(lambda x : 'variante' if x >= 3 else 'control')

# %%
df3.groupby('grupo')['job_satisfaction'].sum()
# Out:
# grupo
# control      913
# variante    3403
# Name: job_satisfaction, dtype: int64

# %%
df3[df3['grupo']=='control']['job_satisfaction'].isnull().sum()
# Out:
# 0

# %%
df3[df3['grupo']=='variante']['job_satisfaction'].isnull().sum()
# Out:
# 0

# %%
df3.head()
# Out:
#    job_satisfaction  performance_rating  total_working_years  \
# 0                 3                 3.0                  NaN
# 1                 3                 3.0                 34.0
# 2                 4                 3.0                 22.0
# 3                 3                 3.0                  NaN
# 4                 1                 3.0                  NaN
#
#    percent_salary_hike  attrition     grupo
# 0                 0.13      False  variante
# 1                 0.14      False  variante
# 2                 0.11      False  variante
# 3                 0.19      False  variante
# 4                 0.12      False   control

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20,10))
sns.barplot(x = "job_satisfaction", 
            hue = "attrition", 
            y = 'grupo',
            data = df3, 
            ax = axes[0][0], 
            palette = "magma")
sns.barplot(x = "performance_rating", 
            hue = "attrition", 
            y = 'grupo',
            data = df3, 
            ax = axes[0][1], 
            palette = "magma")
sns.barplot(x = "total_working_years", 
            hue = "attrition", 
            y = 'grupo',
            data = df3, 
            ax = axes[1][0], 
            palette = "magma")
sns.barplot(x = "percent_salary_hike", 
            hue = "attrition", 
            y = 'grupo',
            data = df3, 
            ax = axes[1][1], 
            palette = "magma")

axes[0][0].set_title('Job satisfaction')
axes[0][1].set_title('performance rating')
axes[1][0].set_title('total working years')
axes[1][1].set_title('percent salary hike')
# Out:
# Text(0.5, 1.0, 'percent salary hike')

# %%
df2.head()
# Out:
#    environment_satisfaction  job_satisfaction  relationship_satisfaction  \
# 0                       1.0                 3                          3
# 1                       3.0                 3                          1
# 2                       3.0                 4                          4
# 3                       1.0                 3                          2
# 4                       1.0                 1                          4
#
#    attrition     grupo
# 0      False  variante
# 1      False  variante
# 2      False  variante
# 3      False  variante
# 4      False   control

# %%
fig, axes = plt.subplots(nrows = 3, ncols = 1, figsize = (10,20))
sns.barplot(y = "job_satisfaction", 
            hue = "attrition", 
            x = 'grupo',
            data = df2, 
            ax = axes[0], 
            palette = "magma")
sns.barplot(y = "environment_satisfaction", 
            hue = "attrition", 
            x = 'grupo',
            data = df2, 
            ax = axes[1], 
            palette = "magma")
sns.barplot(y = "relationship_satisfaction", 
            hue = "attrition", 
            x = 'grupo',
            data = df2, 
            ax = axes[2], 
            palette = "magma")

axes[0].set_title('job')
axes[1].set_title('environment')
axes[2].set_title('relationship')
# Out:
# Text(0.5, 1.0, 'relationship')

# %%
df3.columns
# Out:
# Index(['job_satisfaction', 'performance_rating', 'total_working_years',
#        'percent_salary_hike', 'attrition', 'grupo'],
#       dtype='object')

# %%
for columna in df3.columns[:4]:
    normalidad(df3, columna)
# Out:
# Para la columna job_satisfaction los datos no siguen una distribución normal.
# Para la columna performance_rating los datos siguen una distribución normal.
# Para la columna total_working_years los datos siguen una distribución normal.
# Para la columna percent_salary_hike los datos no siguen una distribución normal.

# %%
for col in ['performance_rating', 'total_working_years']:
    homogeneidad(df3, 'grupo', col)
# Out:
# Para la métrica performance_rating las varianzas no son homogéneas entre grupos.
# Para la métrica total_working_years las varianzas no son homogéneas entre grupos.

# %%
test_man_whitney(df3, ['job_satisfaction', 'performance_rating', 'total_working_years',
       'percent_salary_hike'], 'control', 'variante', 'grupo')
# Out:
# Para la métrica job_satisfaction las medianas son diferentes.
# Para la métrica performance_rating las medianas son iguales.
# Para la métrica total_working_years las medianas son iguales.
# Para la métrica percent_salary_hike las medianas son iguales.

# %%
contingency_table = pd.crosstab(df_p['Grupo'], df_p['Clics'])

# Realizar la prueba de proporciones
chi2, p_value, _, _ = chi2_contingency(contingency_table)

# Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa en las tasas de clics entre el Grupo de Control y el Grupo de Prueba.")
    print("\n ---------- \n")
    print("""
          Los resultados sugieren que existe evidencia estadística para afirmar que las medias de las muestras son distintas. 
          Por lo tanto, nuestro nuevo sistema tiene los efectos deseados y deberíamos cambiar la nueva versión de anuncios   
          """)
else:
    print("No hay evidencia de una diferencia significativa en las tasas de clics entre los grupos.")
    print("\n ---------- \n")
    print(""" 
          Los resultados sugieren que no existe evidencia estadística para afirmar que las medias de las muestras son distintas,
          por lo que la nueva campaña no esta ayudando a nuestro problema. 
          """)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../csv-archivos/datos_sql.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work', 'grupo'],
#       dtype='object')

# %%
df.groupby('remote_work')['employee_number'].count()
# Out:
# remote_work
# False    442
# True     477
# Name: employee_number, dtype: int64

# %%
df.groupby('grupo')['environment_satisfaction'].mean()
# Out:
# grupo
# control     2.713971
# variante    2.726316
# Name: environment_satisfaction, dtype: float64

# %%
df.groupby('attrition')['environment_satisfaction'].mean()
# Out:
# attrition
# False    2.771845
# True     2.448560
# Name: environment_satisfaction, dtype: float64

# %% [markdown]
# # VISUALIZACIONES

# %% [markdown]
# distribucion de subidas salariales isa
# - total empresa
# - departamentos
# - generos
# - edad
#
#
# monthly income isa
# - por departamentos
# - por genero

# %%
df2 = df.copy()
df2['grupo_edad'] = df['date_birth'].apply(lambda x: '+40' if x > 1983 else '-40')
df2['grupo_working_years'] = df['total_working_years'].apply(lambda x: '+20' if x > 20 else '-20')

# %% [markdown]
# ## percent salary hike

# %%
sns.barplot(x='grupo_edad', hue='gender', y='percent_salary_hike', data=df2)
plt.title('Subida salarial según género y grupo de edad')
# Out:
# Text(0.5, 1.0, 'Subida salarial según género y grupo de edad')

# %%
sns.barplot(x='grupo_working_years', hue='gender', y='percent_salary_hike', data=df2)
plt.title('Subida salarial según años trabajados en la empresa')
# Out:
# Text(0.5, 1.0, 'Subida salarial según años trabajados en la empresa')

# %%
sns.barplot(x='marital_status', hue='gender', y='percent_salary_hike', data=df2)
plt.title('Subida salarial de aquellos que continúan y se han ido')
# Out:
# Text(0.5, 1.0, 'Subida salarial de aquellos que continúan y se han ido')

# %%
sns.barplot(x='attrition', hue='gender', y='percent_salary_hike', data=df2)
plt.title('Subida salarial por estado civil')
# Out:
# Text(0.5, 1.0, 'Subida salarial por estado civil')

# %% [markdown]
# ## monthly icnome

# %%
sns.barplot(x='grupo_edad', hue='gender', y='monthly_income', data=df2)
plt.title('Salario según género y grupo de edad')
# Out:
# Text(0.5, 1.0, 'Salario según género y grupo de edad')

# %%
sns.barplot(x='grupo_working_years', hue='gender', y='monthly_income', data=df2)
plt.title('Subida salarial según años trabajados en la empresa')
# Out:
# Text(0.5, 1.0, 'Subida salarial según años trabajados en la empresa')

# %%
sns.barplot(x='marital_status', hue='gender', y='monthly_income', data=df2)
plt.title('Subida salarial por estado civil')
# Out:
# Text(0.5, 1.0, 'Subida salarial por estado civil')

# %%
sns.barplot(x='attrition', hue='gender', y='monthly_income', data=df2)
plt.title('Salario mensual de aquellos que continúan y se han ido')
# Out:
# Text(0.5, 1.0, 'Salario mensual de aquellos que continúan y se han ido')

# %%
df_edad = df2.groupby(['grupo_edad', 'gender'])[['monthly_income','percent_salary_hike']].mean()
df_edad
# Out:
#                    monthly_income  percent_salary_hike
# grupo_edad gender
# +40        f          4930.312500             0.150877
#            m          4780.948387             0.151731
# -40        f          9088.309091             0.152838
#            m          9584.152866             0.151682

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20, 10))
sns.barplot(x='grupo_edad', hue='gender', y='monthly_income', data=df2, ax=axes[0][0])
sns.barplot(x='grupo_working_years', hue='gender', y='monthly_income', data=df2, ax=axes[0][1])
sns.barplot(x='marital_status', hue='gender', y='monthly_income', data=df2, ax=axes[1][0])
sns.barplot(x='attrition', hue='gender', y='monthly_income', data=df2, ax=axes[1][1])


axes[0][0].set_title('Salario mensual según años trabajados en la empresa')
axes[0][1].set_title('Salario mensual de aquellos según años en la empresa')
axes[1][0].set_title('Salario mensual por estado civil')
axes[1][1].set_title('Salario mensual de antiguos y actuales empleados')
# Out:
# Text(0.5, 1.0, 'Salario mensual de antiguos y actuales empleados')

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (20, 10))
sns.barplot(x='grupo_edad', hue='gender', y='percent_salary_hike', data=df2, ax=axes[0][0])
sns.barplot(x='grupo_working_years', hue='gender', y='percent_salary_hike', data=df2, ax=axes[0][1])
sns.barplot(x='marital_status', hue='gender', y='percent_salary_hike', data=df2, ax=axes[1][0])
sns.barplot(x='attrition', hue='gender', y='percent_salary_hike', data=df2, ax=axes[1][1])

axes[0][0].set_title('Subida salarial según años trabajados en la empresa')
axes[0][1].set_title('Subida salarial de quellos según años en la empresa')
axes[1][0].set_title('Subida salarial por estado civil')
axes[1][1].set_title('Subida salarial de antiguos y actuales empleados')
# Out:
# Text(0.5, 1.0, 'Subida salarial de antiguos y actuales empleados')

# %%
pd.crosstab(df2['grupo_edad'], df2['grupo_working_years'])
# Out:
# grupo_working_years  +20   -20
# grupo_edad
# +40                    4  1013
# -40                  134   428

# %%
df2[(df2['grupo_edad'] == '+40')&(df2['grupo_working_years']=='-20')].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df2[(df2['grupo_edad'] == '+40')&(df2['grupo_working_years']=='-20')].mean()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:11666, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11658 @doc(make_doc("mean", ndim=2))
#   11659 def mean(
#   11660     self,
#    (...)
#   11664     **kwargs,
#   11665 ):
# > 11666     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11667     if isinstance(result, Series):
#   11668         result = result.__finalize__(self, method="mean")
#
# ...

# %%
sns.countplot(x='grupo_edad', hue='attrition', data=df2)
# Out:
# <Axes: xlabel='grupo_edad', ylabel='count'>

# %%
sns.countplot(x='grupo_working_years', hue='attrition', data=df2)
# Out:
# <Axes: xlabel='grupo_working_years', ylabel='count'>

# %%
def intervalo_confianza(continente, columna, nivel_confianza):
    media = df[df['continent'] == continente][columna].mean()
    error = stats.sem(df[df['continent'] == continente][columna].dropna())
    nivel_conf = nivel_confianza
    gr_libertad = len(df[df['continent'] == continente][columna].dropna())
    v_critico = stats.t.ppf((1+nivel_conf)/2, df= gr_libertad)
    lim_inf = media - v_critico * error
    lim_sup = media + v_critico * error

    print(columna, 'en', continente)
    print('Límite inferior:', lim_inf)
    print('Límite superior:', lim_sup)

# %%
df2['attrition'].shape
# Out:
# (1579,)

# %%
df2['testeo'] =

# %%
df2[(df2['grupo_edad']=='+40')&(df2['grupo_working_years']=='-20')&(df2['attrition']==True)].shape
# Out:
# (190, 35)

# %%
df2[(df2['grupo_edad']=='-40')&(df2['grupo_working_years']=='-20')&(df2['attrition']==True)].shape
# Out:
# (55, 35)

# %%
df2[(df2['grupo_edad']=='+40')&(df2['grupo_working_years']=='+20')&(df2['attrition']==True)].shape
# Out:
# (1, 35)

# %%
df2[(df2['grupo_edad']=='-40')&(df2['grupo_working_years']=='+20')&(df2['attrition']==True)].shape
# Out:
# (9, 35)

# %% [markdown]
# ## chi cuadrado

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_8960\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df2.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work', 'grupo',
#        'grupo_edad', 'grupo_working_years'],
#       dtype='object')

# %%
dfA = df2[(df2['grupo_edad']=='+40')&(df2['grupo_working_years']=='-20')]
dfB = df2[(df2['grupo_edad']=='-40') | (df2['grupo_working_years']=='+20')]

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df2['grupo_testeo'] = np.where(
    (df2['grupo_edad'] == '+40') & (df2['grupo_working_years'] == '-20'), 'A',
    np.where((df2['grupo_edad'] == '-40') | (df2['grupo_working_years'] == '+20'), 'B', ''))

# %%
tab_cont = pd.crosstab(df2['attrition'], df2['grupo_testeo'])

# %%
tab_cont
# Out:
# grupo_testeo    A    B
# attrition
# False         823  501
# True          190   65

# %%
chi2, p_value,_,_ = chi2_contingency(tab_cont)

# %%
p_value
# Out:
# 0.00022039308044641026

# %%
import seaborn as sns
sns.countplot(x=df2[df2['attrition']==True]['grupo_testeo'], data=df2)
# Out:
# <Axes: xlabel='grupo_testeo', ylabel='count'>

# %%
dfA
# Out:
#       attrition business_travel  daily_rate department  distance_from_home  \
# 12        False             NaN       201.0        NaN                  10
# 18        False             NaN       819.0        NaN                  13
# 21        False             NaN       515.0        NaN                   1
# 22        False             NaN      1223.0        NaN                   8
# 24        False          rarely       928.0        NaN                  42
# ...         ...             ...         ...        ...                 ...
# 1606      False      frequently      1283.0      sales                   1
# 1607      False             NaN       616.0        NaN                  12
# 1608      False             NaN       498.0        NaN                   3
# 1611      False          rarely       903.0        NaN                  13
# 1612      False              no      1229.0        NaN                   8
#
# ...

# %%
dfB['attrition'].isnull().sum()
# Out:
# 0

# %%
tab_cont = pd.crosstab(dfA['attrition'], dfB['attrition'])
tab_cont
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2[(df2['grupo_edad']=='-40')&(df2['attrition']==True)]

# %%
df2[(df2['grupo_edad']=='-40')&(df2['attrition']==True)]
# Out:
#       attrition business_travel  daily_rate              department  \
# 13         True          rarely      1360.0                     NaN
# 16         True          rarely       286.0                     NaN
# 26         True             NaN       266.0                     NaN
# 81         True          rarely       147.0                     NaN
# 98         True             NaN         NaN                     NaN
# ...         ...             ...         ...                     ...
# 1515       True             NaN       723.0                     NaN
# 1542       True              no       666.0                     NaN
# 1559       True             NaN       143.0                     NaN
# 1600       True             NaN       436.0                     NaN
# 1604       True             NaN      1085.0  research & development
#
#       distance_from_home  education education_field  employee_number  \
# 13                    12          3             NaN             58.0
# ...

# %%
df2[(df2['grupo_working_years']=='-20')&(df2['attrition']==True)]
# Out:
#       attrition business_travel  daily_rate              department  \
# 13         True          rarely      1360.0                     NaN
# 43         True          rarely       885.0                     NaN
# 52         True          rarely       737.0                     NaN
# 132        True          rarely       527.0                     NaN
# 140        True      frequently       481.0                     NaN
# ...         ...             ...         ...                     ...
# 1569       True      frequently       426.0                     NaN
# 1588       True             NaN       654.0  research & development
# 1600       True             NaN       436.0                     NaN
# 1602       True             NaN         NaN                     NaN
# 1604       True             NaN      1085.0  research & development
#
#       distance_from_home  education education_field  employee_number  \
# 13                    12          3             NaN             58.0
# ...

# %%
df2[(df2['grupo_working_years']=='-20')&(df2['attrition']==False)]
# Out:
#       attrition business_travel  daily_rate              department  \
# 0         False             NaN       684.0                     NaN
# 3         False          rarely       359.0                     NaN
# 4         False             NaN      1319.0                     NaN
# 5         False             NaN       117.0  research & development
# 7         False          rarely       635.0                     NaN
# ...         ...             ...         ...                     ...
# 1608      False             NaN       498.0                     NaN
# 1610      False              no       805.0                     NaN
# 1611      False          rarely       903.0                     NaN
# 1612      False              no      1229.0                     NaN
# 1613      False             NaN       566.0                     NaN
#
#       distance_from_home  education   education_field  employee_number  \
# 0                      6          3               NaN            162.0
# ...

# %%
df_edad
# Out:
#                    monthly_income  percent_salary_hike
# grupo_edad gender
# +40        f          4930.312500             0.150877
#            m          4780.948387             0.151731
# -40        f          9088.309091             0.152838
#            m          9584.152866             0.151682

# %%
import pandas as pd
import numpy as np
import random

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")


from itertools import combinations

# %%
media = df2[(df2['gender'] == 'f') & (df2['grupo_edad'] == '+40')]['monthly_income'].mean()
error = stats.sem(df2[(df2['gender'] == 'f') & (df2['grupo_edad'] == '+40')]['monthly_income'].dropna())
nivel_conf = 0.99
gr_libertad = len(df2[(df2['gender'] == 'f') & (df2['grupo_edad'] == '+40')]['monthly_income'].dropna())
v_critico = stats.t.ppf((1+nivel_conf)/2, df= gr_libertad)
lim_inf = media - v_critico * error
lim_sup = media + v_critico * error

print('Límite inferior:', lim_inf)
print('Límite superior:', lim_sup)
# Out:
# Límite inferior: 4342.873705722255
# Límite superior: 5517.751294277745

# %%
media = df2[(df2['gender'] == 'f') & (df2['marital_status'] == 'divorced')]['monthly_income'].mean()
error = stats.sem(df2[(df2['gender'] == 'f') & (df2['marital_status'] == 'divorced')]['monthly_income'].dropna())
nivel_conf = 0.99
gr_libertad = len(df2[(df2['gender'] == 'f') & (df2['marital_status'] == 'divorced')]['monthly_income'].dropna())
v_critico = stats.t.ppf((1+nivel_conf)/2, df= gr_libertad)
lim_inf = media - v_critico * error
lim_sup = media + v_critico * error

print('Límite inferior:', lim_inf)
print('Límite superior:', lim_sup)
# Out:
# Límite inferior: 3749.7563933059796
# Límite superior: 8972.657399797468

# %% [markdown]
# >Se aprecia en la empresa una distribución equitativa del salario en cuanto a género se refiere.
#
# >Los empleados más jóvenes (de 18 a 40 años) reciben sueldos más altos.
#
# >Aquellos que han trabajado más de veinte años en la empresa reciben sueldos más altos que quienes llevan menos tiempo.
#
# >El porcentaje de subida salarial no parecen ir en función de la antigüedad, sino de la performance

# %% [markdown]
# ## calculos

# %%
df['total_working_years'].agg(['max', 'min'])
# Out:
# max    40.0
# min     0.0
# Name: total_working_years, dtype: float64

# %%
df.groupby('gender')['percent_salary_hike'].agg(['mean', 'median'])
# Out:
#             mean  median
# gender
# f       0.151592    0.14
# m       0.151714    0.14

# %%
df.groupby('marital_status')['percent_salary_hike'].agg(['mean', 'median'])
# Out:
#                     mean  median
# marital_status
# divorced        0.150714    0.14
# married         0.149176    0.14
# single          0.149151    0.14

# %%
psh_mayor = df[df['percent_salary_hike'] > df['percent_salary_hike'].mean()][['date_birth', 'percent_salary_hike']]
psh_menor = df[df['percent_salary_hike'] < df['percent_salary_hike'].mean()][['date_birth', 'percent_salary_hike']]

# %%
psh_mayor['date_birth'].agg(['max', 'min'])
# Out:
# max    2005
# min    1963
# Name: date_birth, dtype: int64

# %%
psh_mayor['date_birth'].value_counts()
# Out:
# date_birth
# 1988    36
# 1989    31
# 1992    29
# 1994    27
# 1987    25
# 1993    24
# 1985    24
# 1982    21
# 1983    21
# 1990    20
# 1991    20
# 1997    20
# 1978    20
# 1996    19
# 1981    18
# 1995    17
# 1986    16
# 1984    16
# 1977    15
# 1980    14
# 1974    12
# 1968    11
# 1970    11
# 1976    10
# 1998     9
# 1972     9
# 1999     9
# 2001     8
# 1979     8
# 1967     7
# 1973     7
# 2000     7
# 1971     6
# 1964     5
# 1969     5
# 2002     5
# 2004     5
# 1965     4
# 1975     4
# 2003     4
# 1963     3
# 1966     2
# 2005     1
# Name: count, dtype: int64

# %%
sns.boxplot(x='date_birth', data = psh_mayor)
# Out:
# <Axes: xlabel='date_birth'>

# %%
df.groupby('date_birth')['percent_salary_hike'].agg(['mean', 'median'])
# Out:
#                 mean  median
# date_birth
# 1963        0.164000   0.180
# 1964        0.153000   0.155
# 1965        0.155000   0.135
# 1966        0.148000   0.120
# 1967        0.145882   0.130
# 1968        0.157083   0.150
# 1969        0.143000   0.130
# 1970        0.157368   0.160
# 1971        0.154737   0.150
# 1972        0.154000   0.145
# 1973        0.143871   0.140
# 1974        0.163200   0.150
# 1975        0.140526   0.120
# 1976        0.144815   0.120
# 1977        0.157297   0.140
# 1978        0.158261   0.145
# 1979        0.145294   0.130
# 1980        0.151842   0.140
# 1981        0.148163   0.130
# 1982        0.156977   0.150
# 1983        0.153167   0.140
# 1984        0.155000   0.145
# 1985        0.151475   0.140
# 1986        0.149057   0.140
# 1987        0.151644   0.140
# 1988        0.152683   0.140
# 1989        0.153086   0.140
# 1990        0.150328   0.140
# 1991        0.149531   0.140
# 1992        0.148889   0.130
# ...

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_current_manager', 'date_birth', 'remote_work', 'grupo'],
#       dtype='object')

# %%
df['percent_salary_hike'].isnull().sum()/df.shape[0]
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x='department',
            hue='gender',
            y= 'percent_salary_hike')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.barplot(x='department',
#       2             hue='gender',
#       3             y= 'percent_salary_hike')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
# ...

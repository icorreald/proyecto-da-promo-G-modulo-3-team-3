# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/c/Users/johan/Desktop/Adalab/modulo-3/HR RAW DATA.csv",index_col=0)
df
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
df_31_42= df.iloc[:, 31:42]

# %%
df_31_42
# Out:
#       YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 20                NaN                       15
# 1                 33                NaN                       11
# 2                 22                NaN                       11
# 3                 20                NaN                        5
# 4                 19                NaN                        2
# ...              ...                ...                      ...
# 1609              16                NaN                        3
# 1610               9                NaN                        0
# 1611               8                NaN                        0
# 1612               7                NaN                        0
# 1613               8                NaN                        0
#
#       YEARSWITHCURRMANAGER SameAsMonthlyIncome  DateBirth       Salary  \
# 0                       15             19537,0       1972  1000000000$
# ...

# %%
df_31_42.isnull()
# Out:
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              False                True                    False
# 1              False                True                    False
# 2              False                True                    False
# 3              False                True                    False
# 4              False                True                    False
# ...              ...                 ...                      ...
# 1609           False                True                    False
# 1610           False                True                    False
# 1611           False                True                    False
# 1612           False                True                    False
# 1613           False                True                    False
#
#       YEARSWITHCURRMANAGER  SameAsMonthlyIncome  DateBirth  Salary  \
# 0                    False                False      False   False
# ...

# %%
df_31_42.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1614 entries, 0 to 1613
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearsAtCompany           1614 non-null   int64
#  1   YearsInCurrentRole       34 non-null     object
#  2   YearsSinceLastPromotion  1614 non-null   int64
#  3   YEARSWITHCURRMANAGER     1614 non-null   int64
#  4   SameAsMonthlyIncome      771 non-null    object
#  5   DateBirth                1614 non-null   int64
#  6   Salary                   1614 non-null   int64
#  7   RoleDepartament          302 non-null    object
#  8   NUMBERCHILDREN           0 non-null      float64
#  9   RemoteWork               1614 non-null   bool
# dtypes: bool(1), float64(1), int64(5), object(3)
# memory usage: 127.7+ KB

# %%
df_31_42.isnull().sum()
# Out:
# YearsAtCompany                0
# YearsInCurrentRole         1580
# YearsSinceLastPromotion       0
# YEARSWITHCURRMANAGER          0
# SameAsMonthlyIncome         843
# DateBirth                     0
# Salary                        0
# RoleDepartament            1312
# NUMBERCHILDREN             1614
# RemoteWork                    0
# dtype: int64

# %%
df_31_42.duplicated().sum()
# Out:
# 147

# %%
print(df_31_42.dtypes)
# Out:
# YearsAtCompany               int64
# YearsInCurrentRole          object
# YearsSinceLastPromotion      int64
# YEARSWITHCURRMANAGER         int64
# SameAsMonthlyIncome         object
# DateBirth                    int64
# Salary                      object
# RoleDepartament             object
# NUMBERCHILDREN             float64
# RemoteWork                  object
# dtype: object

# %%
YearsAtCompany               int64  
YearsInCurrentRole          object - NaN / Float
YearsSinceLastPromotion      int64
YEARSWITHCURRMANAGER         int64
SameAsMonthlyIncome         object - NaN /Float
DateBirth                    int64
Salary                      object - Dolar $  - Cambiado. 
RoleDepartament             object  - Cambiado a minus. Habia valores mins y mays mezclados. 
NUMBERCHILDREN             float64 - NaN -Eliminada , todos son nulos. 
RemoteWork                  object -  True/ False - Ok cambiado.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
#NUMBERCHILDREN             1614 nulos , la totalidad
#Eliminamos 

df_31_42.drop(['NUMBERCHILDREN'], axis = 1, inplace=True)

# %%
#RoleDepartment -Mins

df_31_42['RoleDepartament'] = df_31_42['RoleDepartament'].str.lower()
df_31_42
# Out:
#       YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 20                NaN                       15
# 1                 33                NaN                       11
# 2                 22                NaN                       11
# 3                 20                NaN                        5
# 4                 19                NaN                        2
# ...              ...                ...                      ...
# 1609              16                NaN                        3
# 1610               9                NaN                        0
# 1611               8                NaN                        0
# 1612               7                NaN                        0
# 1613               8                NaN                        0
#
#       YEARSWITHCURRMANAGER SameAsMonthlyIncome  DateBirth      Salary  \
# 0                       15             19537,0       1972  1000000000
# ...

# %%
# Salary - Quitar $
df_31_42['Salary'] = df_31_42['Salary'].str.replace('$', '').astype(int)

# %%
df_31_42['Salary']
# Out:
# 0       1000000000
# 1       1000000000
# 2       1000000000
# 3       1000000000
# 4       1000000000
#            ...
# 1609    1000000000
# 1610    1000000000
# 1611    1000000000
# 1612    1000000000
# 1613    1000000000
# Name: Salary, Length: 1614, dtype: int64

# %%
#RemoteWork

df_31_42['RemoteWork'] = df_31_42['RemoteWork'].replace(['yes', '1'], True).replace(['0', 'false'], False)

# Convertir la columna a tipo booleano
df_31_42['RemoteWork'] = df_31_42['RemoteWork'].astype(bool)

# %%
df_31_42['RemoteWork']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1609    False
# 1610     True
# 1611     True
# 1612     True
# 1613    False
# Name: RemoteWork, Length: 1614, dtype: bool

# %%
df_31_42['YearsInCurrentRole']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1609    NaN
# 1610    NaN
# 1611    NaN
# 1612    NaN
# 1613    NaN
# Name: YearsInCurrentRole, Length: 1614, dtype: object

# %%
df_31_42.describe(include = "object").T
# Out:
#                     count unique                  top freq
# YearsInCurrentRole     34     10                  2,0   11
# SameAsMonthlyIncome   771    668               6347,0    4
# RoleDepartament       302    301   MaNAgeR  -  Sales     2

# %%
df_cat = df_31_42.select_dtypes(include = "object")
df_cat
# Out:
#      YearsInCurrentRole SameAsMonthlyIncome  \
# 0                   NaN             19537,0
# 1                   NaN             19999,0
# 2                   NaN             19232,0
# 3                   NaN             17169,0
# 4                   NaN                 NaN
# ...                 ...                 ...
# 1609                NaN             10325,0
# 1610                NaN              4447,0
# 1611                NaN                 NaN
# 1612                NaN                 NaN
# 1613                NaN             10845,0
#
#                            RoleDepartament
# 0                                      NaN
# 1                                      NaN
# 2      ManaGER  -  Research & Development
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1609                                   NaN
# 1610                                   NaN
# ...

# %%
# NO FUNCIONA

for elemento in df_31_42.YearsInCurrentRole:
    if type(elemento) == str:
        df_31_42.YearsInCurrentRole = df_31_42.YearsInCurrentRole.replace(',', '.').astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       3 for elemento in df_31_42.YearsInCurrentRole:
#       4     if type(elemento) == str:
# ----> 5         df_31_42.YearsInCurrentRole = df_31_42.YearsInCurrentRole.replace(',', '.').astype(float)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df_31_42
# Out:
#       YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 20                NaN                       15
# 1                 33                NaN                       11
# 2                 22                NaN                       11
# 3                 20                NaN                        5
# 4                 19                NaN                        2
# ...              ...                ...                      ...
# 1609              16                NaN                        3
# 1610               9                NaN                        0
# 1611               8                NaN                        0
# 1612               7                NaN                        0
# 1613               8                NaN                        0
#
#       YEARSWITHCURRMANAGER SameAsMonthlyIncome  DateBirth      Salary  \
# 0                       15             19537,0       1972  1000000000
# ...

# %% [markdown]
# ##### Resumen
#
# * Pendiente qué hacer con las columnas NAN/FLOAT. Se indica que se verá en prox lecciones cómo tratar los nulos.
# * Pendiente cambiar título columnas. mins/ con  _ ?
#
# - YearsAtCompany               int64
# - YearsInCurrentRole          object - NaN / Float - No se puede pasar a INT. 1580 nulos.
# - YearsSinceLastPromotion      int64
# - YEARSWITHCURRMANAGER         int64
# - SameAsMonthlyIncome         object - NaN /Float - No se puede pasar a INT. 843 nulos.
# - DateBirth                    int64
# - Salary                      object - Dolar $  - Cambiado.  ✅
# - RoleDepartament             object  - Cambiado a minus.✅ Habia valores mins y mays mezclados.  1312 nulos.
# - NUMBERCHILDREN             float64 - NaN -Eliminada , todos son nulos.  ✅
# - RemoteWork                  object -  True/ False - Ok cambiado. ✅

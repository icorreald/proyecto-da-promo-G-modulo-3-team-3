# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../csv-archivos/HR RAW DATA.csv")

# %%
df
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0              0  51        No            NaN    684,0$
# 1              1  52        No            NaN    699,0$
# 2              2  42        No  travel_rarely    532,0$
# 3              3  47        No  travel_rarely    359,0$
# 4              4  46        No            NaN   1319,0$
# ...          ...  ..       ...            ...       ...
# 1609        1609  36       Yes  travel_rarely    530,0$
# 1610        1610  45        No     non-travel    805,0$
# 1611        1611  39        No  travel_rarely    903,0$
# 1612        1612  36        No     non-travel   1229,0$
# 1613        1613  46        No            NaN    566,0$
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN                 6          3               NaN
# 1                          NaN                 1          4     Life Sciences
# ...

# %%
df["employeenumber"].dtype
# Out:
# dtype('O')

# %%
fila, columna = df[df == 'thirty-two'].stack().index[0]
print(fila)
print(columna)
# Out:
# 1293
# Age

# %%
#Columna Age

# %%
df.iloc[31,1] = 47

# %%
df.iloc[79,1] = 58

# %%
df.iloc[216,1] = 36

# %%
df.iloc[357,1] = 55

# %%
df.iloc[411,1] = 52

# %%
df.iloc[426,1] = 31

# %%
df.iloc[593,1] = 30

# %%
df.iloc[1198,1] = 26

# %%
df.iloc[1226,1] = 37

# %%
df.iloc[1293,1] = 32

# %%
df.iloc[1325,1] = 24

# %%
df.iloc[1584,1] = 32

# %%
df['Age'] = df['Age'].astype(int)

# %%
#Attrition

# %%
df['Attrition'] = df['Attrition'].replace('No', 'False'). replace('Yes', 'True')

# %%
df['Attrition'] = df['Attrition'].astype(bool)

# %%
#Business Travel

# %%
df['BusinessTravel'] = df['BusinessTravel'].replace("non-travel", "no").replace("travel_rarely", "rarely").replace("travel_frequently", "frequently")

# %%
#Daily Rate

# %%
df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")
# Out:
# /tmp/ipykernel_31307/315446460.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["DailyRate"] = df["DailyRate"].str.replace("$","").str.replace(",",".")

# %%
df["DailyRate"] = df["DailyRate"].astype(float)

# %%
#Department

# %%
df["Department"] = df["Department"].str.strip()

# %%
#Distance From Home

# %%
df["DistanceFromHome"] = abs(df["DistanceFromHome"])

# %%
#Education Field

# %%
df["EducationField"] = df["EducationField"].str.lower()

# %%
#employeecount

# %%
df = df.drop('employeecount', axis=1)

# %%
#employeenumber

# %%
df["employeenumber"] = df["employeenumber"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
#NO CONSIGO PASAR A INT LO HE PROBADO TUTOOOO

# %% [markdown]
# ## ISA

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['JobRole'] = df['JobRole'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.lower().str.strip()

# %%
df['MaritalStatus'] = df['MaritalStatus'].str.replace('marreid', 'married')
df['Gender'] = df['Gender'].replace(1, 'F').replace(0, 'M')

# %%
df['HourlyRate'] = df['HourlyRate'].replace('Not Available', np.nan)

# %% [markdown]
# ## MIRNA

# %%
df['Over18'].value_counts()
# Out:
# Y    713
# Name: Over18, dtype: int64

# %%
df['Over18'] = df['Over18'].replace('Y', True)

# %%
df['OverTime'] = df['OverTime'].replace({'Yes': True, 'No': False})

# %%
df["PercentSalaryHike"] = (df["PercentSalaryHike"]).astype(float) / 100

# %%
df['PerformanceRating'] = df['PerformanceRating'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['StandardHours'] = df['StandardHours'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['TOTALWORKINGYEARS'] = df["TOTALWORKINGYEARS"].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %% [markdown]
# ## JOHANNA

# %%
df['Salary'] = df['Salary'].str.replace('$', '').astype(int)
# Out:
# /tmp/ipykernel_31307/1531604466.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary'] = df['Salary'].str.replace('$', '').astype(int)

# %%
df['RoleDepartament'] = df['RoleDepartament'].str.lower()

# %%
df.drop(['NUMBERCHILDREN'], axis = 1, inplace=True)

# %%
df['RemoteWork'] = df['RemoteWork'].replace(['Yes', 'yes' '1'], True).replace(['0', 'false'], False)

# %%
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
df['SameAsMonthlyIncome'] = df['SameAsMonthlyIncome'].str.replace(',', '.').astype(float).fillna(99999).astype(int)

# %%
# cambiamos nulos === 99999
df['RoleDepartament'] == df['RoleDepartament'].fillna(99999)

# eliminamos el role job
lista_vacia = []

for dato in df['RoleDepartament']:
    dato = str(dato)
    if '-' in dato:
        dato = dato.split('- ')
        lista_vacia.append(dato[-1].strip())
    else:
        lista_vacia.append(dato)


# volcamos datos nuevos
df['RoleDepartament'] = lista_vacia

# %%
# cambiamos todos los 99999 a NaN
df.replace(99999, None, inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.sample(15)
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 654          654   27       True     frequently     1297.0
# 1174        1174   33       True         rarely      134.0
# 1172        1172   22       True         rarely        NaN
# 127          127   35       True            NaN      619.0
# 456          456   43       True         rarely      244.0
# 1206        1206   59       True            NaN      326.0
# 1179        1179   49       True            NaN     1091.0
# 1130        1130   58       True     frequently     1216.0
# 230          230   40       True             no      218.0
# 280          280   40       True     frequently     1395.0
# 671          671   50       True            NaN        NaN
# 1210        1210   30       True            NaN     1358.0
# 1163        1163   40       True         rarely     1322.0
# 1411        1411   26       True         rarely      474.0
# 115          115   34       True            NaN      470.0
#
# ...

# %%
df['EducationField'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 0              0   51       True            NaN      684.0
# 1              1   52       True            NaN      699.0
# 2              2   42       True         rarely      532.0
# 3              3   47       True         rarely      359.0
# 4              4   46       True            NaN     1319.0
# ...          ...  ...        ...            ...        ...
# 1609        1609   36       True         rarely      530.0
# 1610        1610   45       True             no      805.0
# 1611        1611   39       True         rarely      903.0
# 1612        1612   36       True             no     1229.0
# 1613        1613   46       True            NaN      566.0
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                        NaN                 6          3               NaN
# 1                        NaN                 1          4     life sciences
# ...

# %% [markdown]
# ##### Actualización Johanna- NaN, nan - None

# %%
columnas_a_actualizar = ['BusinessTravel', 'Department', 'EducationField','MaritalStatus','Over18','OverTime','employeenumber','HourlyRate','MonthlyIncome','PerformanceRating','WORKLIFEBALANCE']

df[columnas_a_actualizar] = df[columnas_a_actualizar].replace({pd.NA: None})

# %%
#RoleDepartment
df.replace("nan", None, inplace=True)

# %%
# DailyRate

df['DailyRate'] = df['DailyRate'].where(pd.notna(df['DailyRate']), None)

# %%
df
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 0              0   51       True           None      684.0
# 1              1   52       True           None      699.0
# 2              2   42       True         rarely      532.0
# 3              3   47       True         rarely      359.0
# 4              4   46       True           None     1319.0
# ...          ...  ...        ...            ...        ...
# 1609        1609   36       True         rarely      530.0
# 1610        1610   45       True             no      805.0
# 1611        1611   39       True         rarely      903.0
# 1612        1612   36       True             no     1229.0
# 1613        1613   46       True           None      566.0
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                       None                 6          3              None
# 1                       None                 1          4     life sciences
# ...

# %%
df.sample(66)
# Out:
#       Unnamed: 0  Age  Attrition BusinessTravel  DailyRate  \
# 477          477   35       True           None     1395.0
# 496          496   27       True           None      975.0
# 1100        1100   49       True           None        NaN
# 260          260   30       True         rarely      911.0
# 1120        1120   53       True           None      661.0
# ...          ...  ...        ...            ...        ...
# 745          745   52       True     frequently      322.0
# 338          338   32       True           None      929.0
# 633          633   34       True         rarely      401.0
# 1183        1183   31       True           None     1365.0
# 546          546   29       True     frequently      490.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 477                     None                 9          4        medical
# 496                     None                 7          3           None
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                     0
# Age                            0
# Attrition                      0
# BusinessTravel               772
# DailyRate                    124
# Department                  1312
# DistanceFromHome               0
# Education                      0
# EducationField               745
# employeenumber               431
# EnvironmentSatisfaction        0
# Gender                         0
# HourlyRate                    84
# JobInvolvement                 0
# JobLevel                       0
# JobRole                        0
# JobSatisfaction                0
# MaritalStatus                651
# MonthlyIncome                843
# MonthlyRate                    0
# NUMCOMPANIESWORKED             0
# Over18                       901
# OverTime                     676
# PercentSalaryHike              0
# PerformanceRating            195
# RelationshipSatisfaction       0
# StandardHours               1195
# StockOptionLevel               0
# ...

# %% [markdown]
# revisar:
#
# - cambiar NaN (o nan) por None ------JOHANNA
# - department: poner lower ------- MIRNA
# - cambiar nombres columnas ------ INÉS
# - hacer int: ------ ISA
#     - WORKLIFEBALANCE: hacer int (**y revisar**)
#     - DailyRate

# %%
# 23/03/2024 - Pruebas

# Resumen : Tablas Department y Role Department misma información, se puede unir job role con una de ellas creando una nueva, y asi se eliminan las 3.
# Tabla environment_satisfaction se indica que los niveles van comprendidos del 1 al 4 , pero hay muchos fuera de este rango. ¿Eliminamos tabla , o modificamos esos valores?

# %%
df = pd.read_csv("../csv-archivos/datos_limpios.csv", index_col= 0)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 df = pd.read_csv("../csv-archivos/datos_limpios.csv", index_col= 0)
#       2 df
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over18',
#        'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work'],
#       dtype='object')

# %%
# RemoteWork: Si el empleado puede teletrabajar o no. Tipo O, True 655, False 614 , NaN. 
df["remote_work"].value_counts()
# Out:
# True     655
# False    614
# Name: remote_work, dtype: int64

# %%
#performance_rating :   Calificación de rendimiento del empleado.
# float, nulos 195 , 3.3 (1205), 4.0 (214)

df["performance_rating"].info
# Out:
# <bound method Series.info of 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0
#        ...
# 1609    NaN
# 1610    3.0
# 1611    3.0
# 1612    NaN
# 1613    3.0
# Name: performance_rating, Length: 1614, dtype: float64>

# %%
# relationship_satisfaction : Nivel de satisfacción en las relaciones interpersonales del empleado.Calificación de rendimiento del empleado.
# Valores : 3 (504) , 4 (468) , 2 (339), 1(303)

df["relationship_satisfaction"].unique()
# Out:
# array([3, 1, 4, 2])

# %%
# num_companies_worked : Número de compañías en las que el empleado ha trabajado
# Tipo int, Nulos 0 ,  7 (84), 0(226), 1(573), 3(169) ,2(156), 4 (157),8(51),9(59), 5(66) , 6 (73)

df["num_companies_worked"].isnull().sum()
# Out:
# 0

# %%
# stock_option_level : Nivel de opciones de compra de acciones del empleado.
# Tipo int, Nulos 0 , 0(687), 1(666) , 2(172) ,3 (89)

df["stock_option_level"].value_counts()
# Out:
# 0    687
# 1    666
# 2    172
# 3     89
# Name: stock_option_level, dtype: int64

# %%
# Attrition: Indica si el empleado ha dejado la empresa ("No" significa que no ha dejado la empresa y "Yes" significa que ha dejado la empresa).
# Tipo bool, True 1355, False 259, nulos 0

df["attrition"].dtype
# Out:
# dtype('bool')

# %%
# business_travel : Describe la frecuencia de los viajes relacionados con el trabajo del empleado.

# Tipo object, nulos (772), 'rarely'(586), 'frequently'(165), 'no'(91)

df["business_travel"].unique()
# Out:
# array([nan, 'rarely', 'frequently', 'no'], dtype=object)

# %%
# department : departamento en el que trabaja el empleado
#  tipo  ,nulos , 'research & development'(196), 'sales'(91), 'human resources'(15)

df["department"].value_counts()
# Out:
# research & development    196
# sales                      91
# human resources            15
# Name: department, dtype: int64

# %%
# role_departament : El departamento y el rol del empleado.
#nulos 1312 (), sales 91 , rrhh 15, research 196. Object.
df["role_departament"].value_counts()
# Out:
# research & development    196
# sales                      91
# human resources            15
# Name: role_departament, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over18',
#        'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work'],
#       dtype='object')

# %%
#employee_number :  Un número de identificación único para el empleado.
# Nulos 431, 1079 con id = 1510 ¿resto?

df["employee_number"].value_counts()
# Out:
# 482.0     2
# 530.0     2
# 507.0     2
# 517.0     2
# 522.0     2
#          ..
# 161.0     1
# 164.0     1
# 190.0     1
# 194.0     1
# 2040.0    1
# Name: employee_number, Length: 1079, dtype: int64

# %%
df["employee_number"].isnull().sum()
# Out:
# 431

# %%
employee_numbers = df['employee_number'].tolist()

# %%
employee_numbers
# Out:
# [162.0,
#  259.0,
#  319.0,
#  nan,
#  nan,
#  1900.0,
#  81.0,
#  387.0,
#  nan,
#  999.0,
#  1035.0,
#  nan,
#  nan,
#  58.0,
#  nan,
#  558.0,
#  825.0,
#  nan,
#  nan,
#  nan,
#  1712.0,
#  73.0,
#  nan,
#  820.0,
#  nan,
#  nan,
#  nan,
#  1294.0,
#  nan,
#  1774.0,
#  1815.0,
#  1993.0,
#  32.0,
#  100.0,
#  nan,
#  244.0,
#  327.0,
#  373.0,
#  nan,
#  729.0,
#  830.0,
#  nan,
#  981.0,
#  1042.0,
#  1080.0,
#  1995.0,
#  145.0,
#  158.0,
#  391.0,
#  436.0,
#  nan,
#  1527.0,
#  nan,
#  1866.0,
#  2026.0,
#  nan,
#  107.0,
#  170.0,
#  nan,
#  215.0,
#  304.0,
#  529.0,
#  691.0,
#  692.0,
#  1005.0,
#  1024.0,
#  1039.0,
#  1225.0,
#  1375.0,
#  nan,
#  nan,
#  nan,
#  1661.0,
#  1668.0,
#  1698.0,
#  nan,
#  1937.0,
#  2017.0,
#  117.0,
#  131.0,
#  153.0,
#  nan,
#  307.0,
#  nan,
#  374.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  524.0,
#  569.0,
#  899.0,
#  nan,
#  1014.0,
#  nan,
#  1117.0,
#  1238.0,
#  nan,
#  1277.0,
#  nan,
#  1541.0,
#  1666.0,
#  1696.0,
#  1805.0,
# ...

# %%
df["employee_number"].duplicated().sum()
# Out:
# 534

# %%
df.duplicated(subset = "employee_number").sum()
# Out:
# 534

# %%
duplicados = df[df.duplicated(subset=["employee_number"])]["employee_number"]

# %%
lista_duplicados = duplicados.tolist()

# %%
lista_duplicados
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
df_duplicados = pd.DataFrame({"employee_number": lista_duplicados})
df_duplicados
# Out:
#      employee_number
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 529            967.0
# 530            972.0
# 531              NaN
# 532            990.0
# 533              NaN
#
# [534 rows x 1 columns]

# %%
employee_numbers
# Out:
# [162.0,
#  259.0,
#  319.0,
#  nan,
#  nan,
#  1900.0,
#  81.0,
#  387.0,
#  nan,
#  999.0,
#  1035.0,
#  nan,
#  nan,
#  58.0,
#  nan,
#  558.0,
#  825.0,
#  nan,
#  nan,
#  nan,
#  1712.0,
#  73.0,
#  nan,
#  820.0,
#  nan,
#  nan,
#  nan,
#  1294.0,
#  nan,
#  1774.0,
#  1815.0,
#  1993.0,
#  32.0,
#  100.0,
#  nan,
#  244.0,
#  327.0,
#  373.0,
#  nan,
#  729.0,
#  830.0,
#  nan,
#  981.0,
#  1042.0,
#  1080.0,
#  1995.0,
#  145.0,
#  158.0,
#  391.0,
#  436.0,
#  nan,
#  1527.0,
#  nan,
#  1866.0,
#  2026.0,
#  nan,
#  107.0,
#  170.0,
#  nan,
#  215.0,
#  304.0,
#  529.0,
#  691.0,
#  692.0,
#  1005.0,
#  1024.0,
#  1039.0,
#  1225.0,
#  1375.0,
#  nan,
#  nan,
#  nan,
#  1661.0,
#  1668.0,
#  1698.0,
#  nan,
#  1937.0,
#  2017.0,
#  117.0,
#  131.0,
#  153.0,
#  nan,
#  307.0,
#  nan,
#  374.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  524.0,
#  569.0,
#  899.0,
#  nan,
#  1014.0,
#  nan,
#  1117.0,
#  1238.0,
#  nan,
#  1277.0,
#  nan,
#  1541.0,
#  1666.0,
#  1696.0,
#  1805.0,
# ...

# %%
numero_buscado = 1.0

# Verificar si el número buscado está en la lista
if numero_buscado in employee_numbers:
    print(f"El número {numero_buscado} está en la lista.")
else:
    print(f"El número {numero_buscado} no está en la lista.")

# Obtener el índice del número buscado en la lista
indice_numero = employee_numbers.index(numero_buscado)
indice_numero
# Out:
# El número 1.0 no está en la lista.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 10>()
#       7     print(f"El número {numero_buscado} no está en la lista.")
#       9 # Obtener el índice del número buscado en la lista
# ---> 10 indice_numero = employee_numbers.index(numero_buscado)
#      11 indice_numero
#
# ValueError: 1.0 is not in list

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over18',
#        'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work'],
#       dtype='object')

# %%
df
# Out:
#        age  attrition business_travel  daily_rate              department  \
# 0     51.0      False             NaN       684.0                     NaN
# 1     52.0      False             NaN       699.0                     NaN
# 2     42.0      False          rarely       532.0  research & development
# 3     47.0      False          rarely       359.0                     NaN
# 4     46.0      False             NaN      1319.0                     NaN
# ...    ...        ...             ...         ...                     ...
# 1609  36.0       True          rarely       530.0                     NaN
# 1610  45.0      False              no       805.0                     NaN
# 1611  39.0      False          rarely       903.0                     NaN
# 1612  36.0      False              no      1229.0                     NaN
# 1613  46.0      False             NaN       566.0                     NaN
#
#       distance_from_home  education   education_field  employee_number  \
# ...

# %%
# environment_satisfaction Nivel de satisfacción del empleado en relación con su entorno de trabajo. Con valores que estan comprendidos entre el 1 y el 4, siendo el 4 el nivel de máxima satisfacción. SE SALEN DEL TOPE.
# Tipo int, Nulos 0 , resto : [ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
    #    13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
    #    17, 20, 26, 43])
df["environment_satisfaction"].unique()
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43])

# %%
df["environment_satisfaction"].info
# Out:
# <bound method Series.info of 0        1
# 1        3
# 2        3
# 3        1
# 4        1
#         ..
# 1609     3
# 1610     3
# 1611    13
# 1612     1
# 1613     4
# Name: environment_satisfaction, Length: 1614, dtype: int64>

# %%
df["environment_satisfaction"].value_counts()
# Out:
# 4     460
# 3     459
# 1     298
# 2     297
# 12      7
# 35      6
# 13      6
# 14      5
# 24      5
# 47      5
# 36      4
# 48      4
# 41      4
# 46      4
# 42      4
# 45      3
# 11      3
# 22      3
# 17      3
# 18      3
# 20      3
# 25      3
# 27      3
# 37      2
# 29      2
# 19      2
# 38      2
# 31      2
# 15      2
# 16      2
# 26      1
# 39      1
# 10      1
# 49      1
# 21      1
# 28      1
# 33      1
# 43      1
# Name: environment_satisfaction, dtype: int64

# %%
# job_involvement

# 3 (955) 2 (406)   4 (164)  1 (89)

df["job_involvement"].isnull().sum()
# Out:
# 0

# %%
# job_level :  Nivel jerárquico del empleado en la empresa. Del 1 al 5. 


# [5, 4, 3, 2, 1], 0 nulos, tipo int

df["job_level"].value_counts()
# Out:
# 2    597
# 1    586
# 3    242
# 4    113
# 5     76
# Name: job_level, dtype: int64

# %%
df["job_role"].value_counts()
# Out:
# sales executive              369
# research scientist           314
# laboratory technician        278
# manufacturing director       158
# healthcare representative    149
# manager                      111
# sales representative          90
# research director             88
# human resources               57
# Name: job_role, dtype: int64

# %%
df["job_role"].unique()
# Out:
# array(['research director', 'manager', 'sales executive',
#        'manufacturing director', 'research scientist',
#        'healthcare representative', 'laboratory technician',
#        'sales representative', 'human resources'], dtype=object)

# %%
df["job_role"].dtype
# Out:
# dtype('O')

# %%
copia_df = df.copy()

# %%
# Valores nulos, a desconocido para la nueva columna. 

copia_df['role_departament'].fillna('unknown', inplace=True)
copia_df['job_role'].fillna('unknown', inplace=True)

# %%
# Unir en una sola columna, los datos de las 3 : job_role, role_department, department  ?????

#Concat?

# job_role_department = pd.concat([copia_df['job_role'], copia_df['department']], ignore_index=True)

# copia_df['job_role_department'] = job_role_department

# %%
# Unir los datos de las columnas 'role_department' y 'job_role'

copia_df['department_job_role'] = copia_df['role_departament'] + ' - ' + copia_df['job_role']

# %%
#Podriamos eliminar las 3 columnas , dejando solo : department_job_role

# %%
copia_df.drop(columns=["job_role_department"], inplace=True)

# %%
copia_df
# Out:
#        age  attrition business_travel  daily_rate              department  \
# 0     51.0      False             NaN       684.0                     NaN
# 1     52.0      False             NaN       699.0                     NaN
# 2     42.0      False          rarely       532.0  research & development
# 3     47.0      False          rarely       359.0                     NaN
# 4     46.0      False             NaN      1319.0                     NaN
# ...    ...        ...             ...         ...                     ...
# 1609  36.0       True          rarely       530.0                     NaN
# 1610  45.0      False              no       805.0                     NaN
# 1611  39.0      False          rarely       903.0                     NaN
# 1612  36.0      False              no      1229.0                     NaN
# 1613  46.0      False             NaN       566.0                     NaN
#
#       distance_from_home  education   education_field  employee_number  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over18',
#        'over_time', 'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'standard_hours', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'same_as_monthly_income', 'date_birth', 'salary', 'role_departament',
#        'remote_work', 'job_role_department'],
#       dtype='object')

# %%
# job_satisfaction : Nivel de satisfacción del empleado con su trabajo.
# Nulos 0 , 4 (514),  3(481), 1 (317) ,2 (302).
df["job_satisfaction"].unique()
# Out:
# array([3, 4, 1, 2])

# %%
df["job_satisfaction"].value_counts()
# Out:
# 4    514
# 3    481
# 1    317
# 2    302
# Name: job_satisfaction, dtype: int64

# %%
df["job_satisfaction"].isnull().sum()
# Out:
# 0

# %%
#work_life_balance : Equilibrio entre trabajo y vida personal del empleado.
#Nulos 0, 3.0(913), 2.0(359) ,4.0(155), 1.0 (79)

df["work_life_balance"].value_counts()
# Out:
# 3.0    913
# 2.0    359
# 4.0    155
# 1.0     79
# Name: work_life_balance, dtype: int64

# %%
df["work_life_balance"].isnull().sum()
# Out:
# 108

# %%
df = pd.read_csv('../csv-archivos/limpieza_final.csv')

# %%
def currently_working (valor):

    if np.isnan(valor):
        return False
    else:
        return True

# %%
df["currently_working"] = df["employee_number"].apply(currently_working)

# %%
df["currently_working"].value_counts()
# Out:
# currently_working
# True     1160
# False     420
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1580, 35)

# %%
df["employee_number"].isnull().sum()
# Out:
# 420

# %%
nulos = df[df["currently_working"]== False]

# %%
nulos['employee_number'].isnull().sum()
# Out:
# 40

# %%
no_nulos =df[df["currently_working"]== True]

# %%
no_nulos['employee_number'].isnull().sum()
# Out:
# 0

# %%
df_copia = df.copy()

# %%
df_copia = df.copy()

# %%
auto = pd.Series(range(2069,3900))
auto
# Out:
# 0       2069
# 1       2070
# 2       2071
# 3       2072
# 4       2073
#         ...
# 1826    3895
# 1827    3896
# 1828    3897
# 1829    3898
# 1830    3899
# Length: 1831, dtype: int64

# %% [markdown]
# # NULOS + NO_NULOS

# %%
nulos.shape
# Out:
# (420, 35)

# %%
nulos['employee_number'] = nulos['employee_number'].fillna(auto)
# Out:
# C:\Users\Isabel\AppData\Local\Temp\ipykernel_6564\3594184428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nulos['employee_number'] = nulos['employee_number'].fillna(auto)

# %%
nulos['employee_number'].min()
# Out:
# 2072.0

# %%
nulos['employee_number'].max()
# Out:
# 3648.0

# %%
df2 = pd.concat([no_nulos, nulos], axis=0, ignore_index=0)

df2.shape
# Out:
# (1580, 35)

# %%
df.shape
# Out:
# (1580, 35)

# %%
df2.drop(columns='currently_working', axis=1)
# Out:
#       Unnamed: 0  attrition business_travel  daily_rate  \
# 0              0      False             NaN       684.0
# 1              1      False             NaN       699.0
# 2              2      False          rarely       532.0
# 5              5      False             NaN       117.0
# 6              6      False             NaN      1435.0
# ...          ...        ...             ...         ...
# 1568        1601      False             NaN       760.0
# 1569        1602       True             NaN         NaN
# 1574        1607      False             NaN       616.0
# 1577        1611      False          rarely       903.0
# 1579        1613      False             NaN       566.0
#
#                   department  distance_from_home  education   education_field  \
# 0                        NaN                   6          3               NaN
# 1                        NaN                   1          4     life sciences
# ...

# %%
df2.to_csv('../csv-archivos/datos_sql.csv')

# %%
nulos[nulos['attrition']==False]
# Out:
#       Unnamed: 0  attrition business_travel  daily_rate department  \
# 3              3      False          rarely       359.0        NaN
# 4              4      False             NaN      1319.0        NaN
# 8              8      False             NaN      1276.0        NaN
# 11            11      False          rarely      1369.0        NaN
# 12            12      False             NaN       201.0        NaN
# ...          ...        ...             ...         ...        ...
# 1566        1599      False          rarely         NaN        NaN
# 1568        1601      False             NaN       760.0      sales
# 1574        1607      False             NaN       616.0        NaN
# 1577        1611      False          rarely       903.0        NaN
# 1579        1613      False             NaN       566.0        NaN
#
#       distance_from_home  education   education_field  employee_number  \
# 3                      2          4           medical           2072.0
# ...

# %%
# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Realizar los distintos test
# ------------------------------------------------------------------------------

from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway
from sklearn.linear_model import LinearRegression


# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

import scipy.stats as stats

# %% [markdown]
# JOHANNA
# - hacer estudios de satisfaction

# %%
df = pd.read_csv("/mnt/c/Users/johan/Desktop/Adalab/modulo-3/Proyecto/proyecto-da-promo-G-modulo-3-team-3/csv-archivos/limpieza_final.csv",index_col=0)

# %%
df.head()
# Out:
#    attrition business_travel  daily_rate              department  \
# 0      False             NaN       684.0                     NaN
# 1      False             NaN       699.0                     NaN
# 2      False          rarely       532.0  research & development
# 3      False          rarely       359.0                     NaN
# 4      False             NaN      1319.0                     NaN
#
#    distance_from_home  education   education_field  employee_number  \
# 0                   6          3               NaN            162.0
# 1                   1          4     life sciences            259.0
# 2                   4          2  technical degree            319.0
# 3                   2          4           medical              NaN
# 4                   3          3  technical degree              NaN
#
#    environment_satisfaction gender  ...  stock_option_level  \
# 0                       1.0      m  ...                   0
# ...

# %%
df.columns
# Out:
# Index(['attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_in_current_role',
#        'years_since_last_promotion', 'years_with_current_manager',
#        'date_birth', 'remote_work'],
#       dtype='object')

# %%
#  Columnas satisfacción : 
# environment_satisfaction : Nivel de satisfacción del empleado en relación con su entorno de trabajo.
# relationship_satisfaction : Nivel de satisfacción en las relaciones interpersonales del empleado.
# work_life_balance : Equilibrio entre trabajo y vida personal del empleado.
# job_satisfaction: Nivel de satisfacción del empleado con su trabajo.

# %% [markdown]
# ##### environment_satisfaction,years_at_company

# %%
# Correlación débil o inexistente.
correlacion = df['monthly_income'].corr(df['years_at_company'])
print(correlacion)
# Out:
# 0.5599714925381448

# %% [markdown]
# ##### environment_satisfaction , relationship_satisfaction

# %%
# Correlación Débil:

#  El valor absoluto del coeficiente de correlación está cerca de 0.
#  Por lo general, se considera una correlación débil si el valor absoluto está por debajo de 0.3.

correlacion = df['environment_satisfaction'].corr(df['relationship_satisfaction'])
print("Correlación de Pearson:", correlacion)
# Out:
# Correlación de Pearson: 0.008897306237052632

# %%
df_correlacion = pd.DataFrame({'Correlación': [correlacion]})

# %%
sns.heatmap(df_correlacion, # sobre que datos queremos hacer el heatmap
            annot = True, # para que nos muestre los valores de cada una de las celdas del heatmap
            fmt = ".2f",  # para que nos redondee a dos decimales
            cmap = "mako", # para establecer el color de la gráfica
            vmax = 1, # para indicar cual es el valor máximo de nuestra escala de colores
            vmin = -1);

# %%
# Gráfico de dispersión
plt.scatter(df['environment_satisfaction'], df['relationship_satisfaction'])
plt.xlabel('environment_satisfaction')
plt.ylabel('relationship_satisfaction')
plt.title('Gráfico de dispersión')
plt.show()

# %%
#Contingencia, Chi Cuadrado. 

# ¿Está asociada la satisfacción en el entorno laboral de forma ignificativa con las relaciones interpersonales? 
# p_value < 0,05 rechazamos H0.Existe diferencia.
# p_value > 0,05 aceptamos H0 , no existe diferencia.  ✅

tabla_contingencia = pd.crosstab(df['environment_satisfaction'], df['relationship_satisfaction'])
chi2, p, _, _ = stats.chi2_contingency(tabla_contingencia)
print("Estadística chi-cuadrado:", chi2)
print("Valor p:", p)
# Out:
# Estadística chi-cuadrado: 4.951119416984058
# Valor p: 0.8385483060731408

# %% [markdown]
# ##### job_satisfaction,department (Media en cuanto al nivel de satisfacción con el trabajo por departamento.)

# %%
# Departamento media más alta : research
media_departameto_satis = df.groupby('department')['job_satisfaction'].mean()
media_departameto_satis
# Out:
# department
# human resources           2.266667
# research & development    2.864583
# sales                     2.727273
# Name: job_satisfaction, dtype: float64

# %%
sns.barplot(x='department', y='job_satisfaction', data=df)
plt.xlabel('department')
plt.ylabel('ob_satisfaction')
plt.title('Media satisfacción del empleado con su trabajo por departamento')
plt.show()

# %% [markdown]
# ##### education, job_sat

# %%
# No hay relación entre el nivel de estudios con la satisfacción de su trabajo. 

correlation = df['education'].corr(df['job_satisfaction'])
correlation
# Out:
# -0.011649671618265191

# %%
correlation = df['remote_work'].corr(df['job_satisfaction'])
correlation

# %% [markdown]
# ##### work_life_balance,remote_work (Análisis de la relación entre el equilibrio trabajo-vida y el trabajo remoto.)

# %%
sns.barplot(x="remote_work", y="work_life_balance", data=df,  palette = "mako");

# %%
contingency_table = pd.crosstab(df_cleaned ['remote_work'], df_cleaned['work_life_balance'])

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Estadístico Chi-cuadrado: {chi2}")
print(f"Valor p: {p}")
print(f"Grados de libertad : {dof}")
# Out:
# Estadístico Chi-cuadrado: 2.0820438117191724
# Valor p: 0.5555539555079687
# Grados de libertad : 3

# %% [markdown]
# - valor p < 0.05 rechazamos la hipotesis nula, hay diferencia significativa entre las variables.
# - valor p > 0.05 no podemos rechazar H0, no hay suficiente diferencia significativa.

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='remote_work', y='work_life_balance', data=df, ci=None)
plt.xlabel('Remote Work')
plt.ylabel('Work Life Balance')
plt.title('Chi 2')
plt.xticks(ticks=[0, 1], labels=['False', 'True'])
plt.show()

# %%
df["business_travel"].value_counts()
# Out:
# rarely        576
# frequently    160
# no             90
# Name: business_travel, dtype: int64

# %%
correlacion4 = df['relationship_satisfaction'].corr(df['job_level']) # Correlación muy débil. 
print("Correlación de Pearson:", correlacion4)
# Out:
# Correlación de Pearson: 0.021139201618744028

# %% [markdown]
# ##### work_life_balance, job_level

# %%
# ¿Interfiere el equilibrio entre trabajo y vida personal del empleado según el nivel jerarquico?

chi2, p, _, _ = chi2_contingency(pd.crosstab(df['work_life_balance'], df['job_level']))
print("Valor de Chi-cuadrado:", chi2)
print("Valor p:", p)
# Out:
# Valor de Chi-cuadrado: 5.646685252791244
# Valor p: 0.4639080161316075

# %%
# p_value < 0,05 rechazamos H0.Existe diferencia.
# p_value > 0,05 aceptamos H0 , no existe diferencia.  ✅

# %%
media = df.groupby('remote_work')['work_life_balance'].mean()
media
# Out:
# remote_work
# False    2.735552
# True     2.765009
# Name: work_life_balance, dtype: float64

# %%
media = df.groupby('department')['work_life_balance'].mean()
media
# Out:
# department
# human resources           2.933333
# research & development    2.645161
# sales                     2.797619
# Name: work_life_balance, dtype: float64

# %% [markdown]
# ##### Gender, y work life balance.

# %%
# Calcular la media de work_life_balance para cada género - Por muy poco , no hay apenas diferencia. 

media_por_genero = df.groupby('gender')['work_life_balance'].mean()
print(media_por_genero)

# Comparar las medias entre géneros
if media_por_genero['m'] > media_por_genero['f']:
    print("Los hombres tienen un mejor nivel de satisfacción en work_life_balance.")
elif media_por_genero['m'] < media_por_genero['f']:
    print("Las mujeres tienen un mejor nivel de satisfacción en work_life_balance.")
else:
    print("No hay diferencia en el nivel de satisfacción entre géneros en work_life_balance.")
# Out:
# gender
# f    2.767677
# m    2.758817
# Name: work_life_balance, dtype: float64
# Las mujeres tienen un mejor nivel de satisfacción en work_life_balance.

# %%
plt.bar(media_por_genero.index, media_por_genero.values, color=['green', 'violet'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ##### Performance_rating(rendimiento) - Relationship_satisfaction

# %%
# No afecta el nivel de rendimiento en el nivel de relaciones interpersonales.

correlacion = df['performance_rating'].corr(df['relationship_satisfaction'])
print("Correlación de Pearson:", correlacion)
# Out:
# Correlación de Pearson: -0.015446247807991269

# %%
# performance_rating - relationship_satisfaction 

# Gráfico de dispersión
sns.scatterplot(x='performance_rating', y='relationship_satisfaction', data=df)
plt.title('Relación entre rendimiento y satisfacción en las relaciones interpersonales')
plt.xlabel('Rendimiento')
plt.ylabel('Satisfacción en relaciones interpersonales')
plt.show()

# Gráfico de regresión
sns.lmplot(x='performance_rating', y='relationship_satisfaction', data=df)
plt.title('Regresión entre rendimiento y satisfacción en las relaciones interpersonales')
plt.xlabel('Rendimiento')
plt.ylabel('Satisfacción en relaciones interpersonales')
plt.show()

# %% [markdown]
# ##### Marital status, relationship_satisfaction

# %%
sns.boxplot(x='marital_status', y='relationship_satisfaction', data=df)
plt.title('Distribución de satisfacción en relaciones interpersonales por estado civil')
plt.xlabel('Estado Civil')
plt.ylabel('Nivel de satisfacción en relaciones interpersonales')
plt.show()

# %%
media_por_status = df.groupby('marital_status')['relationship_satisfaction'].mean()
print(media_por_status)
# Out:
# marital_status
# divorced    2.765306
# married     2.691765
# single      2.852201
# Name: relationship_satisfaction, dtype: float64

# %%
# total_working_years, job_satisfaction

# %%
correlacion = df['total_working_years'].corr(df['job_satisfaction'])
print(correlacion)
# Out:
# -0.029613974951938717

# %%
df.head()
# Out:
#    attrition business_travel  daily_rate              department  \
# 0      False             NaN       684.0                     NaN
# 1      False             NaN       699.0                     NaN
# 2      False          rarely       532.0  research & development
# 3      False          rarely       359.0                     NaN
# 4      False             NaN      1319.0                     NaN
#
#    distance_from_home  education   education_field  employee_number  \
# 0                   6          3               NaN            162.0
# 1                   1          4     life sciences            259.0
# 2                   4          2  technical degree            319.0
# 3                   2          4           medical              NaN
# 4                   3          3  technical degree              NaN
#
#    environment_satisfaction gender  ...  stock_option_level  \
# 0                       1.0      m  ...                   0
# ...

# %%
# Contar la cantidad de empleados con attrition=True
cantidad_attrition_true = df[df['attrition'] == True].shape[0]

print("Cantidad de empleados que se han marchado (attrition=True):", cantidad_attrition_true)
# Out:
# Cantidad de empleados que se han marchado (attrition=True): 255

# %%
# Filtrar empleados con attrition=True y percent_salary_hike igual a cero
attrition_true_no_hike = df[(df['attrition'] == True) & (df['percent_salary_hike'] == 0)]

# Verificar si hay algún empleado con attrition=True que no haya tenido aumento de salario
if not attrition_true_no_hike.empty:
    print("Hay empleados con attrition=True que no han tenido aumento de salario.")
    print(attrition_true_no_hike)
else:
    print("Todos los empleados con attrition=True han tenido aumento de salario.")
# Out:
# Todos los empleados con attrition=True han tenido aumento de salario.

# %%
# Filtrar empleados que se han marchado (attrition=True)
attrition_true_data = df[df['attrition'] == True]

# Seleccionar las columnas relevantes (attrition y percent_salary_hike)
attrition_true_data = attrition_true_data[['attrition', 'percent_salary_hike']]

print("Datos de los empleados que se han marchado con su respectivo porcentaje de aumento salarial:")
print(attrition_true_data)
# Out:
# Datos de los empleados que se han marchado con su respectivo porcentaje de aumento salarial:
#       attrition  percent_salary_hike
# 13         True                 0.12
# 16         True                 0.12
# 26         True                 0.15
# 43         True                 0.16
# 52         True                 0.17
# ...         ...                  ...
# 1569       True                 0.11
# 1588       True                 0.13
# 1600       True                 0.16
# 1602       True                 0.14
# 1604       True                 0.13
#
# [255 rows x 2 columns]

# %%
max_percent_salary_hike_attrition_true = attrition_true_data['percent_salary_hike'].max()
max_percent_salary_hike_attrition_true
# Out:
# 0.25

# %%
# ¿Puede influir en la rotación que no tengan teletrabajo? 91 empleados, no tenian teletrabajo de los 255 que se han marchado. 

# Filtrar empleados con attrition=True y remote_work=False
attrition_true_no_remote_work = df[(df['attrition'] == True) & (df['remote_work'] == False)]

# Verificar si hay empleados con attrition=True y remote_work=False
if not attrition_true_no_remote_work.empty:
    print("Los siguientes empleados con attrition=True no tenían remote work:")
    print(attrition_true_no_remote_work)
else:
    print("Todos los empleados con attrition=True tenían remote work.")
# Out:
# Los siguientes empleados con attrition=True no tenían remote work:
#       attrition business_travel  daily_rate department  distance_from_home  \
# 13         True          rarely      1360.0        NaN                  12
# 16         True          rarely       286.0        NaN                   2
# 52         True          rarely       737.0        NaN                  10
# 132        True          rarely       527.0        NaN                   1
# 158        True          rarely       790.0        NaN                  24
# ...         ...             ...         ...        ...                 ...
# 1503       True          rarely       261.0        NaN                  21
# 1506       True             NaN         NaN        NaN                  10
# 1515       True             NaN       723.0        NaN                   8
# 1523       True             NaN       756.0        NaN                   1
# 1542       True              no       666.0        NaN                  29
#
# ...

# %%
# Agrupados por departamento 

plt.figure(figsize=(8, 6))
attrition_true_no_remote_work['department'].value_counts().plot(kind='bar')
plt.title('Departamentos de empleados con attrition=True y remote_work=False')
plt.xlabel('Departamento')
plt.ylabel('Cantidad de empleados')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
attrition_true_no_remote_work['department'].value_counts()
# Out:
# research & development    9
# sales                     7
# human resources           1
# Name: department, dtype: int64

# %%
# Obtener cantidad de empleados con attrition=True y remote_work=False

cantidad_attrition_true_no_remote_work = len(attrition_true_no_remote_work)

print(cantidad_attrition_true_no_remote_work )
# Out:
# 91

# %%
attrition_true_data = df[df['attrition'] == True]

attrition_by_department = attrition_true_data['department'].value_counts()

max_attrition_department = attrition_by_department.idxmax()
max_attrition_count = attrition_by_department.max()

print("Departamento con más casos de attrition=True:", max_attrition_department)
print("Cantidad de casos:", max_attrition_count)

plt.figure(figsize=(8, 6))
attrition_by_department.plot(kind='bar')
plt.title('Número de casos de attrition=True por departamento')
plt.xlabel('Departamento')
plt.ylabel('Cantidad de casos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Departamento con más casos de attrition=True: research & development
# Cantidad de casos: 28

# %% [markdown]
# #### % según el estado civil

# %%
marital_remote = df.groupby('marital_status')['remote_work'].value_counts(normalize=True).unstack()
print(marital_remote)
# Out:
# remote_work        False      True
# marital_status
# divorced        0.506173  0.493827
# marreid         0.480000  0.520000
# married         0.490000  0.510000
# single          0.498054  0.501946

# %%
distribution.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribución de teletrabajo por estado civil')
plt.xlabel('Estado Civil')
plt.ylabel('Proporción de Teletrabajo')
plt.xticks(rotation=45)
plt.legend(title='Teletrabajo', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### ¿Qué género teletrabaja más? Los hombres TT más.

# %%
df_teletrabajo = df[df['remote_work'] == True]

teletrabajo_por_genero = df_teletrabajo.groupby('gender').size()

total_teletrabajo = teletrabajo_por_genero.sum()

porcentaje_teletrabajo_por_genero = (teletrabajo_por_genero / total_teletrabajo) * 100

fig, ax = plt.subplots()
ax.bar(porcentaje_teletrabajo_por_genero.index, porcentaje_teletrabajo_por_genero.values, color=['blue', 'orange'])
ax.set_title('Porcentaje de teletrabajo por género (solo entre los que teletrabajan)')
ax.set_xlabel('Género')
ax.set_ylabel('Porcentaje de teletrabajo')
ax.set_ylim(0, 100)
plt.show()

print(porcentaje_teletrabajo_por_genero)
# Out:
# gender
# f    37.264151
# m    62.735849
# dtype: float64

# %%
attrition_by_gender = df.groupby('gender')['attrition'].value_counts()
print(attrition_by_gender)
# Out:
# gender  attrition
# f       False        534
#         True          95
# m       False        791
#         True         160
# Name: attrition, dtype: int64

# %%
sns.countplot(data=df, x='gender', hue='attrition')
plt.title('Attrition por género')
plt.xlabel('Género')
plt.ylabel('Cantidad')
plt.legend(title='Attrition', loc='upper right')
plt.show()

# %% [markdown]
# #### Departamento que menos teletrabaja es RRHH pero el % de los que se van es más alto en R&D.

# %%
df_teletrabajo = df[df['remote_work'] == True]

teletrabajo_por_departamento = df_teletrabajo.groupby('department').size()

departamento_menos_teletrabajo = teletrabajo_por_departamento.idxmin()

numero_personas_teletrabajo_menos = teletrabajo_por_departamento.min()

print("El departamento que menos teletrabaja es:", departamento_menos_teletrabajo)
print("Número de personas que teletrabajan en el departamento con menos teletrabajo:", numero_personas_teletrabajo_menos)
# Out:
# El departamento que menos teletrabaja es: human resources
# Número de personas que teletrabajan en el departamento con menos teletrabajo: 5

# %%
plt.figure(figsize=(8, 8))
plt.pie(teletrabajo_por_departamento, labels=teletrabajo_por_departamento.index, autopct='%1.1f%%', startangle=140)
plt.title('Porcentaje de personas que teletrabajan por departamento',color='white')
plt.axis('equal') 
plt.show()

# %% [markdown]
# #### Relación con distance from home

# %%
from scipy.stats import pearsonr, ttest_ind, f_oneway

# %%
df["remote_work"].isnull().sum()
# Out:
# 341

# %%
df_cleaned = df.dropna(subset=['remote_work'])

# %%
# No parece haber una relación lineal significativa entre la variable "remote_work" y "distance_from_home".
# La correlación de Pearson es 0.0155, lo cual indica una correlación muy débil entre las variables.
pearson_corr, pearson_pval = pearsonr(df_cleaned['remote_work'], df_cleaned['distance_from_home'])
print("Correlación de Pearson:", pearson_corr)
print("Valor p:", pearson_pval)
# Out:
# Correlación de Pearson: 0.015520544676063508
# Valor p: 0.585206305987562

# %% [markdown]
# #### Cantidad de personas que se han ido , que no teletrabajaban y además el nivel de satisfacción en el ambiente laboral es bajo (1-2)

# %%
df["remote_work"].value_counts()
# Out:
# True     636
# False    603
# Name: remote_work, dtype: int64

# %%
# valores de 1 o 2 en 'environment_satisfaction'
filtered_df = df[df['environment_satisfaction'].isin([1, 2])]

# Contar cuántos de ellos teletrabajan
teletrabajo_count = filtered_df['remote_work'].sum()

print("Cantidad de personas con satisfacción del ambiente 1 o 2 que teletrabajan:", teletrabajo_count)
# Out:
# Cantidad de personas con satisfacción del ambiente 1 o 2 que teletrabajan: 223

# %%
#  (attrition=True)
attrition_df = df[df['attrition'] == True]

# Contar cuántos de ellos estaban en el nivel de satisfacción del ambiente 1 o 2 y no teletrabajaban. 
count_attrition_teletrabajo = attrition_df[(attrition_df['environment_satisfaction'].isin([1, 2])) & (attrition_df['remote_work'] == False)].shape[0]

print("Cantidad de personas que se han ido y estaban en nivel de satisfacción 1 o 2 y no teletrabajaban:", count_attrition_teletrabajo)
# Out:
# Cantidad de personas que se han ido y estaban en nivel de satisfacción 1 o 2 y no teletrabajaban: 46

# %% [markdown]
# #### Distribucion por genero
# - total
# - teletrabajo
# - attrition

# %%
distribucion_genero = df['gender'].value_counts(normalize=True) * 100
distribucion_genero

plt.bar(distribucion_genero.index, distribucion_genero.values,color=['green', 'orange'])
plt.title('Distribución por género')
plt.xlabel('Género')
plt.ylabel('Porcentaje')
plt.show()
print(distribucion_genero)
# Out:
# m    60.189873
# f    39.810127
# Name: gender, dtype: float64

# %%
df_teletrabajo = df[df['remote_work'] == True]

teletrabajo_por_genero = df_teletrabajo.groupby('gender').size()

total_teletrabajo = teletrabajo_por_genero.sum()

porcentaje_teletrabajo_por_genero = (teletrabajo_por_genero / total_teletrabajo) * 100

porcentaje_teletrabajo_por_genero

plt.figure(figsize=(8, 6))
plt.pie(porcentaje_teletrabajo_por_genero.values, 
        labels=porcentaje_teletrabajo_por_genero.index, 
        autopct='%1.1f%%', 
        colors=['blue', 'orange'],
        textprops={'color':'white'}) 
plt.title('Porcentaje de teletrabajo por género (solo entre los que teletrabajan)', color='white')
plt.show()

# %%
df["gender"].value_counts()
# Out:
# m    951
# f    629
# Name: gender, dtype: int64

# %%
attrition_gender = df.groupby("gender")["attrition"].sum()
attrition_gender
# Out:
# gender
# f     95
# m    160
# Name: attrition, dtype: int64

# %%
total_hombres = (df['gender'] == 'm').sum()
total_mujeres = (df['gender'] == 'f').sum()

hombres_con_attrition = ((df['gender'] == 'm') & (df['attrition'] == True)).sum()
mujeres_con_attrition = ((df['gender'] == 'f') & (df['attrition'] == True)).sum()

porcentaje_attrition_hombres = (hombres_con_attrition / total_hombres) * 100
porcentaje_attrition_mujeres = (mujeres_con_attrition / total_mujeres) * 100

print(f"Porcentaje de hombres que han dejado la empresa: {porcentaje_attrition_hombres:.2f}%")
print(f"Porcentaje de mujeres que han dejado la empresa: {porcentaje_attrition_mujeres:.2f}%")


plt.bar(['Hombres', 'Mujeres'], [porcentaje_attrition_hombres, porcentaje_attrition_mujeres], color=['cyan', 'purple'])
plt.title('Porcentaje de empleados que han dejado la empresa por género')
plt.ylabel('Porcentaje')
plt.show()
# Out:
# Porcentaje de hombres que han dejado la empresa: 16.82%
# Porcentaje de mujeres que han dejado la empresa: 15.10%

# %% [markdown]
# #### Distribución por edades

# %%
from datetime import datetime

current_year = datetime.now().year
df['age'] = current_year - df['date_birth']


plt.figure(figsize=(10, 6))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución por edades')
plt.grid(True)
plt.show()

# %%
# Dividir en dos grupos
df['group'] = pd.cut(df['age'], bins=[18, 40, 65], labels=['18-40', '40-65'])

group_counts = df['group'].value_counts()

plt.figure(figsize=(8, 6))
group_counts.plot(kind='bar', color='olive')
plt.xlabel('Grupo de edad')
plt.ylabel('Cantidad')
plt.title('Distribución por grupos de edad')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()


major_group = group_counts.idxmax()
print("Hay más trabajadores en el grupo:", major_group)
print(group_counts)
# Out:
# Hay más trabajadores en el grupo: 18-40
# 18-40    1018
# 40-65     562
# Name: group, dtype: int64
